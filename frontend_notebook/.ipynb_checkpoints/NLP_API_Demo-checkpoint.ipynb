# %% [markdown]
# # Google Natural Language API Demo
# #### Further Documentation:
# https://cloud.google.com/natural-language
#
# ## Introduction
#
# The Natural Language API has several methods for performing analysis and annotation on your text. Each level of analysis provides valuable information for language understanding. These methods are listed below:
#
# **Sentiment analysis** inspects the given text and identifies the prevailing emotional opinion within the text, especially to determine a writer's attitude as positive, negative, or neutral. This method returns the sentiment of the text as a whole as well as the sentiment of individual sentences within it. Sentiment analysis is performed through the analyzeSentiment method.
#
# **Entity analysis** inspects the given text for known entities (Proper nouns such as public figures, landmarks, and so on. Common nouns such as restaurant, stadium, and so on.) and returns information about those entities. This includes a Wikipedia link (if applicable), the entity type and the salience (a measure of the relevance of the entity to the entire text). Entity analysis is performed with the analyzeEntities method.
#
# **Entity sentiment analysis** inspects the given text for known entities (proper nouns and common nouns), returns information about those entities, and identifies the prevailing emotional opinion of the entity within the text, especially to determine a writer's attitude toward the entity as positive, negative, or neutral. An example of how this might be used is when presented with a sentence that contains a number of different emotions; for example, "I liked the food but the service was terrible". Entity analysis is performed with the analyzeEntitySentiment method.
#
# **Syntactic analysis** extracts linguistic information, breaking up the given text into a series of sentences and tokens (generally, word boundaries), providing further analysis on those tokens. For each word in the text, the API tells you the word's part of speech (noun, verb, adjective, etc.) and how it relates to other words in the sentence. Syntactic Analysis is performed with the analyzeSyntax method.
#
# **Content classification** analyzes text content and returns a content category for the content. Content classification is performed by using the classifyText method.
#
# Each API call also detects and returns the language, if a language is not specified by the caller in the initial request. A full list of supported languages can be found here: https://cloud.google.com/natural-language/docs/languages
#
# Additionally, if you wish to perform several natural language operations on given text using only one API call, the annotateText request can also be used to perform sentiment analysis and entity analysis.

# %% [markdown]
# ## The Natural Language API: Set Up And Examples

# %% [markdown]
# #### Steps to set up Google Natural Language API
#
# Enable the Google Natural Language API:
# Enable Cloud Natural Language API in Google Marketplace: https://console.cloud.google.com/marketplace/product/google/language.googleapis.com
#
# **Set your project ID:**
# export PROJECT_ID=$(gcloud config get-value core/project)
#
# **Create a service account:**
# gcloud iam service-accounts create my-natlang-sa --display-name "my natural language service account"
#
# **Create a Google Application Crendential key file:**
# gcloud iam service-accounts keys create ~/key.json --iam-account my-natlang-sa@${GOOGLE_CLOUD_PROJECT}.iam.gserviceaccount.com
#
# **Set up your environment to use the service account key file:**
# export GOOGLE_APPLICATION_CREDENTIALS="/home/USER/key.json"
#
# **Install/upgrade Google Cloud Language:**
# pip install --user --upgrade google-cloud-language

# %%
pip install --user --upgrade google-cloud-language
# Out:
# Requirement already satisfied: google-cloud-language in /opt/conda/lib/python3.7/site-packages (1.3.0)
# Collecting google-cloud-language
#   Downloading google_cloud_language-2.0.0-py2.py3-none-any.whl (149 kB)
#      |████████████████████████████████| 149 kB 16.2 MB/s eta 0:00:01
# Requirement already satisfied: google-api-core[grpc]<2.0.0dev,>=1.22.2 in /opt/conda/lib/python3.7/site-packages (from google-cloud-language) (1.22.4)
# Requirement already satisfied: proto-plus>=1.10.0 in /opt/conda/lib/python3.7/site-packages (from google-cloud-language) (1.14.2)
# Requirement already satisfied: libcst>=0.2.5 in /opt/conda/lib/python3.7/site-packages (from google-cloud-language) (0.3.17)
# Requirement already satisfied: setuptools>=34.0.0 in /opt/conda/lib/python3.7/site-packages (from google-api-core[grpc]<2.0.0dev,>=1.22.2->google-cloud-language) (54.0.0)
# Requirement already satisfied: google-auth<2.0dev,>=1.21.1 in /opt/conda/lib/python3.7/site-packages (from google-api-core[grpc]<2.0.0dev,>=1.22.2->google-cloud-language) (1.27.0)
# Requirement already satisfied: pytz in /opt/conda/lib/python3.7/site-packages (from google-api-core[grpc]<2.0.0dev,>=1.22.2->google-cloud-language) (2021.1)
# Requirement already satisfied: requests<3.0.0dev,>=2.18.0 in /opt/conda/lib/python3.7/site-packages (from google-api-core[grpc]<2.0.0dev,>=1.22.2->google-cloud-language) (2.25.1)
# Requirement already satisfied: protobuf>=3.12.0 in /opt/conda/lib/python3.7/site-packages (from google-api-core[grpc]<2.0.0dev,>=1.22.2->google-cloud-language) (3.15.3)
# Requirement already satisfied: googleapis-common-protos<2.0dev,>=1.6.0 in /opt/conda/lib/python3.7/site-packages (from google-api-core[grpc]<2.0.0dev,>=1.22.2->google-cloud-language) (1.52.0)
# Requirement already satisfied: six>=1.13.0 in /opt/conda/lib/python3.7/site-packages (from google-api-core[grpc]<2.0.0dev,>=1.22.2->google-cloud-language) (1.15.0)
# Requirement already satisfied: grpcio<2.0dev,>=1.29.0 in /opt/conda/lib/python3.7/site-packages (from google-api-core[grpc]<2.0.0dev,>=1.22.2->google-cloud-language) (1.36.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /opt/conda/lib/python3.7/site-packages (from google-auth<2.0dev,>=1.21.1->google-api-core[grpc]<2.0.0dev,>=1.22.2->google-cloud-language) (0.2.8)
# Requirement already satisfied: rsa<5,>=3.1.4 in /opt/conda/lib/python3.7/site-packages (from google-auth<2.0dev,>=1.21.1->google-api-core[grpc]<2.0.0dev,>=1.22.2->google-cloud-language) (4.7.2)
# Requirement already satisfied: cachetools<5.0,>=2.0.0 in /opt/conda/lib/python3.7/site-packages (from google-auth<2.0dev,>=1.21.1->google-api-core[grpc]<2.0.0dev,>=1.22.2->google-cloud-language) (4.2.1)
# Requirement already satisfied: typing-inspect>=0.4.0 in /opt/conda/lib/python3.7/site-packages (from libcst>=0.2.5->google-cloud-language) (0.6.0)
# Requirement already satisfied: pyyaml>=5.2 in /opt/conda/lib/python3.7/site-packages (from libcst>=0.2.5->google-cloud-language) (5.4.1)
# Requirement already satisfied: typing-extensions>=3.7.4.2 in /opt/conda/lib/python3.7/site-packages (from libcst>=0.2.5->google-cloud-language) (3.7.4.3)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /opt/conda/lib/python3.7/site-packages (from pyasn1-modules>=0.2.1->google-auth<2.0dev,>=1.21.1->google-api-core[grpc]<2.0.0dev,>=1.22.2->google-cloud-language) (0.4.8)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.7/site-packages (from requests<3.0.0dev,>=2.18.0->google-api-core[grpc]<2.0.0dev,>=1.22.2->google-cloud-language) (2020.12.5)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /opt/conda/lib/python3.7/site-packages (from requests<3.0.0dev,>=2.18.0->google-api-core[grpc]<2.0.0dev,>=1.22.2->google-cloud-language) (1.26.3)
# Requirement already satisfied: idna<3,>=2.5 in /opt/conda/lib/python3.7/site-packages (from requests<3.0.0dev,>=2.18.0->google-api-core[grpc]<2.0.0dev,>=1.22.2->google-cloud-language) (2.10)
# Requirement already satisfied: chardet<5,>=3.0.2 in /opt/conda/lib/python3.7/site-packages (from requests<3.0.0dev,>=2.18.0->google-api-core[grpc]<2.0.0dev,>=1.22.2->google-cloud-language) (4.0.0)
# Requirement already satisfied: mypy-extensions>=0.3.0 in /opt/conda/lib/python3.7/site-packages (from typing-inspect>=0.4.0->libcst>=0.2.5->google-cloud-language) (0.4.3)
# Installing collected packages: google-cloud-language
# Successfully installed google-cloud-language-2.0.0
# Note: you may need to restart the kernel to use updated packages.

# %%
# Import google-cloud-language
# Make sure that you have installed or upgraded to the latest google-cloud-language using pip
from google.cloud import language_v1 as language
import pandas as pd
#Print all columns and all rows in a panda dataframe
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)

# %% [markdown]
# #### Set up functions to call Google Natural Language API
# Here are some examples of the API in action <br>
# Sentiment Analysis:

# %%
# Code from Google at https://codelabs.developers.google.com/codelabs/cloud-natural-language-python3#7
# Probably would be better off changing all the functions to follow the Google standard ones from the codelab, and then making 
# small modifications to the rest of the code to make it all work together.

def analyze_text_sentiment(text):
    client = language.LanguageServiceClient()
    document = language.Document(content=text, type_=language.Document.Type.PLAIN_TEXT)

    response = client.analyze_sentiment(document=document)

    sentiment = response.document_sentiment
    results = dict(
        text=text,
        score=f"{sentiment.score:.1%}",
        magnitude=f"{sentiment.magnitude:.1%}",
    )
    for k, v in results.items():
        print(f"{k:10}: {v}")
    
    # Get sentiment for all sentences in the document
    sentence_sentiment = []
    for sentence in response.sentences:
        item={}
        item["text"]=sentence.text.content
        item["sentiment score"]=sentence.sentiment.score
        item["sentiment magnitude"]=sentence.sentiment.magnitude
        sentence_sentiment.append(item)
    
    return sentence_sentiment

# %%
text = "Stocks are going down on the NASDAQ"
analyze_text_sentiment(text)
# Out:
# text      : Stocks are going down on the NASDAQ
# score     : -70.0%
# magnitude : 70.0%
# [{'text': 'Stocks are going down on the NASDAQ',
#   'sentiment score': -0.699999988079071,
#   'sentiment magnitude': 0.699999988079071}]

# %% [markdown]
# Syntactic Analysis:

# %%
# Syntax Analysis
def gcp_analyze_syntax(text, debug=0):
    """
    Analyzing Syntax in a String

    Args:
      text The text content to analyze
    """

    client = language.LanguageServiceClient()
    document = language.Document(content=text, type_=language.Document.Type.PLAIN_TEXT)
    response = client.analyze_syntax(document=document)
    
    output = []   
    # Loop through tokens returned from the API
    for token in response.tokens:
        word = {}
        # Get the text content of this token. Usually a word or punctuation.
        text = token.text  

        # Get the part of speech information for this token.
        # Parts of spech are as defined in:
        # http://www.lrec-conf.org/proceedings/lrec2012/pdf/274_Paper.pdf
        part_of_speech = token.part_of_speech
        # Get the tag, e.g. NOUN, ADJ for Adjective, et al.
        
        # Get the dependency tree parse information for this token.
        # For more information on dependency labels:
        # http://www.aclweb.org/anthology/P13-2017
        dependency_edge = token.dependency_edge   
        
        word["word"]=text.content
        word["begin_offset"]=text.begin_offset        
        word["part_of_speech"]=language.PartOfSpeech.Tag(part_of_speech.tag).name
        
        # Get the voice, e.g. ACTIVE or PASSIVE
        word["Voice"]=language.PartOfSpeech.Voice(part_of_speech.voice).name
        word["Tense"]=language.PartOfSpeech.Tense(part_of_speech.tense).name
        
        # See API reference for additional Part of Speech information available
        # Get the lemma of the token. Wikipedia lemma description
        # https://en.wikipedia.org/wiki/Lemma_(morphology)        
        word["Lemma"]=token.lemma
        word["index"]=dependency_edge.head_token_index
        word["Label"]=language.DependencyEdge.Label(dependency_edge.label).name
        
        if debug:
            print(u"Token text: {}".format(text.content))
            print(
                u"Location of this token in overall document: {}".format(text.begin_offset)
            ) 
            print(
                u"Part of Speech tag: {}".format(
                    language.PartOfSpeech.Tag(part_of_speech.tag).name
                )
            )        

            print(u"Voice: {}".format(language.PartOfSpeech.Voice(part_of_speech.voice).name))
            # Get the tense, e.g. PAST, FUTURE, PRESENT, et al.
            print(u"Tense: {}".format(language.PartOfSpeech.Tense(part_of_speech.tense).name))

            print(u"Lemma: {}".format(token.lemma))

            print(u"Head token index: {}".format(dependency_edge.head_token_index))
            print(
                u"Label: {}".format(language.DependencyEdge.Label(dependency_edge.label).name)
            )
        
        output.append(word)
        

    # Get the language of the text, which will be the same as
    # the language specified in the request or, if not specified,
    # the automatically-detected language.
    if debug:
        print(u"Language of the text: {}".format(response.language))
    return (output)

# %%
gcp_analyze_syntax(text)
# Out:
# [{'word': 'Stocks',
#   'begin_offset': -1,
#   'part_of_speech': 'NOUN',
#   'Voice': 'VOICE_UNKNOWN',
#   'Tense': 'TENSE_UNKNOWN',
#   'Lemma': 'stock',
#   'index': 2,
#   'Label': 'NSUBJ'},
#  {'word': 'are',
#   'begin_offset': -1,
#   'part_of_speech': 'VERB',
#   'Voice': 'VOICE_UNKNOWN',
#   'Tense': 'PRESENT',
#   'Lemma': 'be',
#   'index': 2,
#   'Label': 'AUX'},
#  {'word': 'going',
#   'begin_offset': -1,
#   'part_of_speech': 'VERB',
#   'Voice': 'VOICE_UNKNOWN',
#   'Tense': 'PRESENT',
#   'Lemma': 'go',
#   'index': 2,
#   'Label': 'ROOT'},
#  {'word': 'down',
#   'begin_offset': -1,
#   'part_of_speech': 'ADV',
#   'Voice': 'VOICE_UNKNOWN',
#   'Tense': 'TENSE_UNKNOWN',
#   'Lemma': 'down',
#   'index': 2,
#   'Label': 'ADVMOD'},
#  {'word': 'on',
#   'begin_offset': -1,
#   'part_of_speech': 'ADP',
#   'Voice': 'VOICE_UNKNOWN',
#   'Tense': 'TENSE_UNKNOWN',
#   'Lemma': 'on',
#   'index': 2,
#   'Label': 'PREP'},
#  {'word': 'the',
#   'begin_offset': -1,
#   'part_of_speech': 'DET',
#   'Voice': 'VOICE_UNKNOWN',
#   'Tense': 'TENSE_UNKNOWN',
#   'Lemma': 'the',
#   'index': 6,
#   'Label': 'DET'},
#  {'word': 'NASDAQ',
#   'begin_offset': -1,
#   'part_of_speech': 'NOUN',
#   'Voice': 'VOICE_UNKNOWN',
#   'Tense': 'TENSE_UNKNOWN',
#   'Lemma': 'NASDAQ',
#   'index': 4,
#   'Label': 'POBJ'}]

# %% [markdown]
# Entity Analysis:

# %%
# Entity Analysis
def gcp_analyze_entities(text, debug=0):
    """
    Analyzing Entities in a String

    Args:
      text_content The text content to analyze
    """

    client = language.LanguageServiceClient()
    document = language.Document(content=text, type_=language.Document.Type.PLAIN_TEXT)
    response = client.analyze_entities(document=document)
    output = []   
    
    # Loop through entitites returned from the API
    for entity in response.entities:
        item = {}
        item["name"]=entity.name
        item["type"]=language.Entity.Type(entity.type_).name
        item["Salience"]=entity.salience
        
        if debug:
            print(u"Representative name for the entity: {}".format(entity.name))

            # Get entity type, e.g. PERSON, LOCATION, ADDRESS, NUMBER, et al
            print(u"Entity type: {}".format(language.Entity.Type(entity.type_).name))

            # Get the salience score associated with the entity in the [0, 1.0] range
            print(u"Salience score: {}".format(entity.salience))

        # Loop over the metadata associated with entity. For many known entities,
        # the metadata is a Wikipedia URL (wikipedia_url) and Knowledge Graph MID (mid).
        # Some entity types may have additional metadata, e.g. ADDRESS entities
        # may have metadata for the address street_name, postal_code, et al.
        for metadata_name, metadata_value in entity.metadata.items():
            item[metadata_name]=metadata_value
            if debug:
                print(u"{}: {}".format(metadata_name, metadata_value))

        # Loop over the mentions of this entity in the input document.
        # The API currently supports proper noun mentions.
        if debug:
            for mention in entity.mentions:
                print(u"Mention text: {}".format(mention.text.content))
                # Get the mention type, e.g. PROPER for proper noun
                print(
                    u"Mention type: {}".format(language.EntityMention.Type(mention.type_).name)
                )
        output.append(item)
    
    # Get the language of the text, which will be the same as
    # the language specified in the request or, if not specified,
    # the automatically-detected language.
    if debug:
        print(u"Language of the text: {}".format(response.language))
    
    return(output)

# %%
gcp_analyze_entities(text)
# Out:
# [{'name': 'Stocks', 'type': 'OTHER', 'Salience': 0.8703455328941345},
#  {'name': 'NASDAQ',
#   'type': 'ORGANIZATION',
#   'Salience': 0.12965445220470428,
#   'wikipedia_url': 'https://en.wikipedia.org/wiki/Nasdaq',
#   'mid': '/m/05dq_'}]

# %% [markdown]
# Content Classification:

# %%
# Content Classification

def gcp_classify_text(text):
    client = language.LanguageServiceClient()
    document = language.Document(content=text, type_=language.Document.Type.PLAIN_TEXT)

    response = client.classify_text(document=document)

    for category in response.categories:
        print("=" * 80)
        print(f"category  : {category.name}")
        print(f"confidence: {category.confidence:.0%}")

# %% [markdown]
# A longer piece of text is required.

# %%
text="Although most people consider piranhas to be quite dangerous, they are, for the most part, entirely harmless. \n\
Piranhas rarely feed on large animals; they eat smaller fish and aquatic plants. When confronted with humans, piranhas’ \n\
first instinct is to flee, not attack. Their fear of humans makes sense. Far more piranhas are eaten by people than people \n\
are eaten by piranhas. If the fish are well-fed, they won’t bite humans."

gcp_classify_text(text)
# Out:
# ================================================================================
# category  : /Hobbies & Leisure
# confidence: 81%
# ================================================================================
# category  : /Pets & Animals/Wildlife
# confidence: 66%

# %% [markdown]
# ## Demo 1 - Process a single news article

# %%
text="Deutsche Bank to Move ‘Heart’ of IT Systems Into Google’s Cloud  \n \
Steven Arons and Nico Grant  \n \
December 4, 2020  \n \
(Bloomberg) -- Deutsche Bank AG expects to ultimately replace large parts of its core banking system with alternatives powered by Alphabet Inc.’s Google, as the German lender embarks on its biggest effort yet to modernize computer systems that have hampered it for years.\n \
The two companies on Friday finalized a cloud computing agreement under which the German lender plans to shift most of its data onto Google servers, technology head Bernd Leukert said in a phone interview. Both firms also agreed to jointly develop products including new lending offerings and retail apps.\n \
The deal will include “applications at the heart of our IT,” Leukert said in an interview, adding that only Deutsche Bank will have the key to decrypt data it transfers to the cloud.\n \
Cutting costs through automation and better technology are a centerpiece of the turnaround plan unveiled by Chief Executive Officer Christian Sewing last year. For Google, the deal is a step toward breaking into the growing cloud business with European banks. The business is currently dominated by Microsoft Corp. and Amazon.com Inc., a Bloomberg News analysis earlier this year showed.\n \
Exactly how much of its systems Deutsche Bank will move into Google’s cloud will depend on “legal, regulatory and data privacy considerations,” Leukert said.\n \
The two companies expect to sell some technology that they develop together to other financial services providers as white-label products and split the revenue, he said.\n \
The contract is set to last at least 10 years and Deutsche Bank expects to make a cumulative return on investment of 1 billion euros ($1.2 billion) through the alliance, Bloomberg News previously reported.\n \
Alphabet last month unveiled an expansion of Google Pay, partnering with banks and retailers in the U.S. to offer consumers new forms of bank accounts, cards and discounts. The upgraded payment system marks the tech giant’s deepest foray yet into the U.S. financial system.  \n \
For more articles like this, please visit us at bloomberg.com \n \
©2020 Bloomberg L.P.©2020 Bloomberg L.P."

# %% [markdown]
# #### Analyze Syntax
# Syntactic Analysis breaks up the given text into a series of sentences and tokens and provides linguistic information about those tokens

# %%
text_syntax=gcp_analyze_syntax(text)
df_syntax = pd.DataFrame(text_syntax)
df_syntax
# Out:
#                word  begin_offset part_of_speech          Voice  \
# 0          Deutsche            -1           NOUN  VOICE_UNKNOWN
# 1              Bank            -1           NOUN  VOICE_UNKNOWN
# 2                to            -1            PRT  VOICE_UNKNOWN
# 3              Move            -1           VERB  VOICE_UNKNOWN
# 4                 ‘            -1          PUNCT  VOICE_UNKNOWN
# 5             Heart            -1           NOUN  VOICE_UNKNOWN
# 6                 ’            -1          PUNCT  VOICE_UNKNOWN
# 7                of            -1            ADP  VOICE_UNKNOWN
# 8                IT            -1           NOUN  VOICE_UNKNOWN
# 9           Systems            -1           NOUN  VOICE_UNKNOWN
# 10             Into            -1            ADP  VOICE_UNKNOWN
# 11           Google            -1           NOUN  VOICE_UNKNOWN
# 12               ’s            -1            PRT  VOICE_UNKNOWN
# 13            Cloud            -1           NOUN  VOICE_UNKNOWN
# 14           Steven            -1           NOUN  VOICE_UNKNOWN
# 15            Arons            -1           NOUN  VOICE_UNKNOWN
# 16              and            -1           CONJ  VOICE_UNKNOWN
# 17             Nico            -1           NOUN  VOICE_UNKNOWN
# 18            Grant            -1           NOUN  VOICE_UNKNOWN
# 19         December            -1           NOUN  VOICE_UNKNOWN
# 20                4            -1            NUM  VOICE_UNKNOWN
# 21                ,            -1          PUNCT  VOICE_UNKNOWN
# 22             2020            -1            NUM  VOICE_UNKNOWN
# 23                (            -1          PUNCT  VOICE_UNKNOWN
# 24        Bloomberg            -1           NOUN  VOICE_UNKNOWN
# 25                )            -1          PUNCT  VOICE_UNKNOWN
# 26               --            -1          PUNCT  VOICE_UNKNOWN
# 27         Deutsche            -1           NOUN  VOICE_UNKNOWN
# 28             Bank            -1           NOUN  VOICE_UNKNOWN
# 29               AG            -1           NOUN  VOICE_UNKNOWN
# 30          expects            -1           VERB  VOICE_UNKNOWN
# 31               to            -1            PRT  VOICE_UNKNOWN
# 32       ultimately            -1            ADV  VOICE_UNKNOWN
# 33          replace            -1           VERB  VOICE_UNKNOWN
# 34            large            -1            ADJ  VOICE_UNKNOWN
# 35            parts            -1           NOUN  VOICE_UNKNOWN
# 36               of            -1            ADP  VOICE_UNKNOWN
# 37              its            -1           PRON  VOICE_UNKNOWN
# 38             core            -1           NOUN  VOICE_UNKNOWN
# 39          banking            -1           NOUN  VOICE_UNKNOWN
# 40           system            -1           NOUN  VOICE_UNKNOWN
# 41             with            -1            ADP  VOICE_UNKNOWN
# 42     alternatives            -1           NOUN  VOICE_UNKNOWN
# 43          powered            -1           VERB  VOICE_UNKNOWN
# 44               by            -1            ADP  VOICE_UNKNOWN
# 45         Alphabet            -1           NOUN  VOICE_UNKNOWN
# 46             Inc.            -1           NOUN  VOICE_UNKNOWN
# 47               ’s            -1            PRT  VOICE_UNKNOWN
# 48           Google            -1           NOUN  VOICE_UNKNOWN
# 49                ,            -1          PUNCT  VOICE_UNKNOWN
# 50               as            -1            ADP  VOICE_UNKNOWN
# 51              the            -1            DET  VOICE_UNKNOWN
# 52           German            -1            ADJ  VOICE_UNKNOWN
# 53           lender            -1           NOUN  VOICE_UNKNOWN
# 54          embarks            -1           VERB  VOICE_UNKNOWN
# 55               on            -1            ADP  VOICE_UNKNOWN
# 56              its            -1           PRON  VOICE_UNKNOWN
# 57          biggest            -1            ADJ  VOICE_UNKNOWN
# 58           effort            -1           NOUN  VOICE_UNKNOWN
# 59              yet            -1            ADV  VOICE_UNKNOWN
# 60               to            -1            PRT  VOICE_UNKNOWN
# 61        modernize            -1           VERB  VOICE_UNKNOWN
# 62         computer            -1           NOUN  VOICE_UNKNOWN
# 63          systems            -1           NOUN  VOICE_UNKNOWN
# 64             that            -1            DET  VOICE_UNKNOWN
# 65             have            -1           VERB  VOICE_UNKNOWN
# 66         hampered            -1           VERB  VOICE_UNKNOWN
# 67               it            -1           PRON  VOICE_UNKNOWN
# 68              for            -1            ADP  VOICE_UNKNOWN
# 69            years            -1           NOUN  VOICE_UNKNOWN
# 70                .            -1          PUNCT  VOICE_UNKNOWN
# 71              The            -1            DET  VOICE_UNKNOWN
# 72              two            -1            NUM  VOICE_UNKNOWN
# 73        companies            -1           NOUN  VOICE_UNKNOWN
# 74               on            -1            ADP  VOICE_UNKNOWN
# 75           Friday            -1           NOUN  VOICE_UNKNOWN
# 76        finalized            -1           VERB  VOICE_UNKNOWN
# 77                a            -1            DET  VOICE_UNKNOWN
# 78            cloud            -1           NOUN  VOICE_UNKNOWN
# 79        computing            -1           NOUN  VOICE_UNKNOWN
# 80        agreement            -1           NOUN  VOICE_UNKNOWN
# 81            under            -1            ADP  VOICE_UNKNOWN
# 82            which            -1            DET  VOICE_UNKNOWN
# 83              the            -1            DET  VOICE_UNKNOWN
# 84           German            -1            ADJ  VOICE_UNKNOWN
# 85           lender            -1           NOUN  VOICE_UNKNOWN
# 86            plans            -1           VERB  VOICE_UNKNOWN
# 87               to            -1            PRT  VOICE_UNKNOWN
# 88            shift            -1           VERB  VOICE_UNKNOWN
# 89             most            -1            ADJ  VOICE_UNKNOWN
# 90               of            -1            ADP  VOICE_UNKNOWN
# 91              its            -1           PRON  VOICE_UNKNOWN
# 92             data            -1           NOUN  VOICE_UNKNOWN
# 93             onto            -1            ADP  VOICE_UNKNOWN
# 94           Google            -1           NOUN  VOICE_UNKNOWN
# 95          servers            -1           NOUN  VOICE_UNKNOWN
# 96                ,            -1          PUNCT  VOICE_UNKNOWN
# 97       technology            -1           NOUN  VOICE_UNKNOWN
# 98             head            -1           NOUN  VOICE_UNKNOWN
# 99            Bernd            -1           NOUN  VOICE_UNKNOWN
# 100         Leukert            -1           NOUN  VOICE_UNKNOWN
# 101            said            -1           VERB  VOICE_UNKNOWN
# 102              in            -1            ADP  VOICE_UNKNOWN
# 103               a            -1            DET  VOICE_UNKNOWN
# 104           phone            -1           NOUN  VOICE_UNKNOWN
# 105       interview            -1           NOUN  VOICE_UNKNOWN
# 106               .            -1          PUNCT  VOICE_UNKNOWN
# 107            Both            -1            DET  VOICE_UNKNOWN
# 108           firms            -1           NOUN  VOICE_UNKNOWN
# 109            also            -1            ADV  VOICE_UNKNOWN
# 110          agreed            -1           VERB  VOICE_UNKNOWN
# 111              to            -1            PRT  VOICE_UNKNOWN
# 112         jointly            -1            ADV  VOICE_UNKNOWN
# 113         develop            -1           VERB  VOICE_UNKNOWN
# 114        products            -1           NOUN  VOICE_UNKNOWN
# 115       including            -1           VERB  VOICE_UNKNOWN
# 116             new            -1            ADJ  VOICE_UNKNOWN
# 117         lending            -1           NOUN  VOICE_UNKNOWN
# 118       offerings            -1           NOUN  VOICE_UNKNOWN
# 119             and            -1           CONJ  VOICE_UNKNOWN
# 120          retail            -1            ADJ  VOICE_UNKNOWN
# 121            apps            -1           NOUN  VOICE_UNKNOWN
# 122               .            -1          PUNCT  VOICE_UNKNOWN
# 123             The            -1            DET  VOICE_UNKNOWN
# 124            deal            -1           NOUN  VOICE_UNKNOWN
# 125            will            -1           VERB  VOICE_UNKNOWN
# 126         include            -1           VERB  VOICE_UNKNOWN
# 127               “            -1          PUNCT  VOICE_UNKNOWN
# 128    applications            -1           NOUN  VOICE_UNKNOWN
# 129              at            -1            ADP  VOICE_UNKNOWN
# 130             the            -1            DET  VOICE_UNKNOWN
# 131           heart            -1           NOUN  VOICE_UNKNOWN
# 132              of            -1            ADP  VOICE_UNKNOWN
# 133             our            -1           PRON  VOICE_UNKNOWN
# 134              IT            -1           NOUN  VOICE_UNKNOWN
# 135               ,            -1          PUNCT  VOICE_UNKNOWN
# 136               ”            -1          PUNCT  VOICE_UNKNOWN
# 137         Leukert            -1           NOUN  VOICE_UNKNOWN
# 138            said            -1           VERB  VOICE_UNKNOWN
# 139              in            -1            ADP  VOICE_UNKNOWN
# 140              an            -1            DET  VOICE_UNKNOWN
# 141       interview            -1           NOUN  VOICE_UNKNOWN
# 142               ,            -1          PUNCT  VOICE_UNKNOWN
# 143          adding            -1           VERB  VOICE_UNKNOWN
# 144            that            -1            ADP  VOICE_UNKNOWN
# 145            only            -1            ADV  VOICE_UNKNOWN
# 146        Deutsche            -1           NOUN  VOICE_UNKNOWN
# 147            Bank            -1           NOUN  VOICE_UNKNOWN
# 148            will            -1           VERB  VOICE_UNKNOWN
# 149            have            -1           VERB  VOICE_UNKNOWN
# 150             the            -1            DET  VOICE_UNKNOWN
# 151             key            -1           NOUN  VOICE_UNKNOWN
# 152              to            -1            PRT  VOICE_UNKNOWN
# 153         decrypt            -1           VERB  VOICE_UNKNOWN
# 154            data            -1           NOUN  VOICE_UNKNOWN
# 155              it            -1           PRON  VOICE_UNKNOWN
# 156       transfers            -1           VERB  VOICE_UNKNOWN
# 157              to            -1            ADP  VOICE_UNKNOWN
# 158             the            -1            DET  VOICE_UNKNOWN
# 159           cloud            -1           NOUN  VOICE_UNKNOWN
# 160               .            -1          PUNCT  VOICE_UNKNOWN
# 161         Cutting            -1           VERB  VOICE_UNKNOWN
# 162           costs            -1           NOUN  VOICE_UNKNOWN
# 163         through            -1            ADP  VOICE_UNKNOWN
# 164      automation            -1           NOUN  VOICE_UNKNOWN
# 165             and            -1           CONJ  VOICE_UNKNOWN
# 166          better            -1            ADJ  VOICE_UNKNOWN
# 167      technology            -1           NOUN  VOICE_UNKNOWN
# 168             are            -1           VERB  VOICE_UNKNOWN
# 169               a            -1            DET  VOICE_UNKNOWN
# 170     centerpiece            -1           NOUN  VOICE_UNKNOWN
# 171              of            -1            ADP  VOICE_UNKNOWN
# 172             the            -1            DET  VOICE_UNKNOWN
# 173      turnaround            -1           NOUN  VOICE_UNKNOWN
# 174            plan            -1           NOUN  VOICE_UNKNOWN
# 175        unveiled            -1           VERB  VOICE_UNKNOWN
# 176              by            -1            ADP  VOICE_UNKNOWN
# 177           Chief            -1           NOUN  VOICE_UNKNOWN
# 178       Executive            -1           NOUN  VOICE_UNKNOWN
# 179         Officer            -1           NOUN  VOICE_UNKNOWN
# 180       Christian            -1           NOUN  VOICE_UNKNOWN
# 181          Sewing            -1           NOUN  VOICE_UNKNOWN
# 182            last            -1            ADJ  VOICE_UNKNOWN
# 183            year            -1           NOUN  VOICE_UNKNOWN
# 184               .            -1          PUNCT  VOICE_UNKNOWN
# 185             For            -1            ADP  VOICE_UNKNOWN
# 186          Google            -1           NOUN  VOICE_UNKNOWN
# 187               ,            -1          PUNCT  VOICE_UNKNOWN
# 188             the            -1            DET  VOICE_UNKNOWN
# 189            deal            -1           NOUN  VOICE_UNKNOWN
# 190              is            -1           VERB  VOICE_UNKNOWN
# 191               a            -1            DET  VOICE_UNKNOWN
# 192            step            -1           NOUN  VOICE_UNKNOWN
# 193          toward            -1            ADP  VOICE_UNKNOWN
# 194        breaking            -1           VERB  VOICE_UNKNOWN
# 195            into            -1            ADP  VOICE_UNKNOWN
# 196             the            -1            DET  VOICE_UNKNOWN
# 197         growing            -1           VERB  VOICE_UNKNOWN
# 198           cloud            -1           NOUN  VOICE_UNKNOWN
# 199        business            -1           NOUN  VOICE_UNKNOWN
# 200            with            -1            ADP  VOICE_UNKNOWN
# 201        European            -1            ADJ  VOICE_UNKNOWN
# 202           banks            -1           NOUN  VOICE_UNKNOWN
# 203               .            -1          PUNCT  VOICE_UNKNOWN
# 204             The            -1            DET  VOICE_UNKNOWN
# 205        business            -1           NOUN  VOICE_UNKNOWN
# 206              is            -1           VERB  VOICE_UNKNOWN
# 207       currently            -1            ADV  VOICE_UNKNOWN
# 208       dominated            -1           VERB        PASSIVE
# 209              by            -1            ADP  VOICE_UNKNOWN
# 210       Microsoft            -1           NOUN  VOICE_UNKNOWN
# 211           Corp.            -1           NOUN  VOICE_UNKNOWN
# 212             and            -1           CONJ  VOICE_UNKNOWN
# 213      Amazon.com            -1           NOUN  VOICE_UNKNOWN
# 214            Inc.            -1           NOUN  VOICE_UNKNOWN
# 215               ,            -1          PUNCT  VOICE_UNKNOWN
# 216               a            -1            DET  VOICE_UNKNOWN
# 217       Bloomberg            -1           NOUN  VOICE_UNKNOWN
# 218            News            -1           NOUN  VOICE_UNKNOWN
# 219        analysis            -1           NOUN  VOICE_UNKNOWN
# 220         earlier            -1            ADV  VOICE_UNKNOWN
# 221            this            -1            DET  VOICE_UNKNOWN
# 222            year            -1           NOUN  VOICE_UNKNOWN
# 223          showed            -1           VERB  VOICE_UNKNOWN
# 224               .            -1          PUNCT  VOICE_UNKNOWN
# 225         Exactly            -1            ADV  VOICE_UNKNOWN
# 226             how            -1            ADV  VOICE_UNKNOWN
# 227            much            -1            ADJ  VOICE_UNKNOWN
# 228              of            -1            ADP  VOICE_UNKNOWN
# 229             its            -1           PRON  VOICE_UNKNOWN
# 230         systems            -1           NOUN  VOICE_UNKNOWN
# 231        Deutsche            -1           NOUN  VOICE_UNKNOWN
# 232            Bank            -1           NOUN  VOICE_UNKNOWN
# 233            will            -1           VERB  VOICE_UNKNOWN
# 234            move            -1           VERB  VOICE_UNKNOWN
# 235            into            -1            ADP  VOICE_UNKNOWN
# 236          Google            -1           NOUN  VOICE_UNKNOWN
# 237              ’s            -1            PRT  VOICE_UNKNOWN
# 238           cloud            -1           NOUN  VOICE_UNKNOWN
# 239            will            -1           VERB  VOICE_UNKNOWN
# 240          depend            -1           VERB  VOICE_UNKNOWN
# 241              on            -1            ADP  VOICE_UNKNOWN
# 242               “            -1          PUNCT  VOICE_UNKNOWN
# 243           legal            -1            ADJ  VOICE_UNKNOWN
# 244               ,            -1          PUNCT  VOICE_UNKNOWN
# 245      regulatory            -1            ADJ  VOICE_UNKNOWN
# 246             and            -1           CONJ  VOICE_UNKNOWN
# 247            data            -1           NOUN  VOICE_UNKNOWN
# 248         privacy            -1           NOUN  VOICE_UNKNOWN
# 249  considerations            -1           NOUN  VOICE_UNKNOWN
# 250               ,            -1          PUNCT  VOICE_UNKNOWN
# 251               ”            -1          PUNCT  VOICE_UNKNOWN
# 252         Leukert            -1           NOUN  VOICE_UNKNOWN
# 253            said            -1           VERB  VOICE_UNKNOWN
# 254               .            -1          PUNCT  VOICE_UNKNOWN
# 255             The            -1            DET  VOICE_UNKNOWN
# 256             two            -1            NUM  VOICE_UNKNOWN
# 257       companies            -1           NOUN  VOICE_UNKNOWN
# 258          expect            -1           VERB  VOICE_UNKNOWN
# 259              to            -1            PRT  VOICE_UNKNOWN
# 260            sell            -1           VERB  VOICE_UNKNOWN
# 261            some            -1            DET  VOICE_UNKNOWN
# 262      technology            -1           NOUN  VOICE_UNKNOWN
# 263            that            -1            DET  VOICE_UNKNOWN
# 264            they            -1           PRON  VOICE_UNKNOWN
# 265         develop            -1           VERB  VOICE_UNKNOWN
# 266        together            -1            ADV  VOICE_UNKNOWN
# 267              to            -1            ADP  VOICE_UNKNOWN
# 268           other            -1            ADJ  VOICE_UNKNOWN
# 269       financial            -1            ADJ  VOICE_UNKNOWN
# 270        services            -1           NOUN  VOICE_UNKNOWN
# 271       providers            -1           NOUN  VOICE_UNKNOWN
# 272              as            -1            ADP  VOICE_UNKNOWN
# 273           white            -1            ADJ  VOICE_UNKNOWN
# 274               -            -1          PUNCT  VOICE_UNKNOWN
# 275           label            -1           NOUN  VOICE_UNKNOWN
# 276        products            -1           NOUN  VOICE_UNKNOWN
# 277             and            -1           CONJ  VOICE_UNKNOWN
# 278           split            -1           VERB  VOICE_UNKNOWN
# 279             the            -1            DET  VOICE_UNKNOWN
# 280         revenue            -1           NOUN  VOICE_UNKNOWN
# 281               ,            -1          PUNCT  VOICE_UNKNOWN
# 282              he            -1           PRON  VOICE_UNKNOWN
# 283            said            -1           VERB  VOICE_UNKNOWN
# 284               .            -1          PUNCT  VOICE_UNKNOWN
# 285             The            -1            DET  VOICE_UNKNOWN
# 286        contract            -1           NOUN  VOICE_UNKNOWN
# 287              is            -1           VERB  VOICE_UNKNOWN
# 288             set            -1           VERB  VOICE_UNKNOWN
# 289              to            -1            PRT  VOICE_UNKNOWN
# 290            last            -1           VERB  VOICE_UNKNOWN
# 291              at            -1            ADV  VOICE_UNKNOWN
# 292           least            -1            ADV  VOICE_UNKNOWN
# 293              10            -1            NUM  VOICE_UNKNOWN
# 294           years            -1           NOUN  VOICE_UNKNOWN
# 295             and            -1           CONJ  VOICE_UNKNOWN
# 296        Deutsche            -1           NOUN  VOICE_UNKNOWN
# 297            Bank            -1           NOUN  VOICE_UNKNOWN
# 298         expects            -1           VERB  VOICE_UNKNOWN
# 299              to            -1            PRT  VOICE_UNKNOWN
# 300            make            -1           VERB  VOICE_UNKNOWN
# 301               a            -1            DET  VOICE_UNKNOWN
# 302      cumulative            -1            ADJ  VOICE_UNKNOWN
# 303          return            -1           NOUN  VOICE_UNKNOWN
# 304              on            -1            ADP  VOICE_UNKNOWN
# 305      investment            -1           NOUN  VOICE_UNKNOWN
# 306              of            -1            ADP  VOICE_UNKNOWN
# 307               1            -1            NUM  VOICE_UNKNOWN
# 308         billion            -1            NUM  VOICE_UNKNOWN
# 309           euros            -1           NOUN  VOICE_UNKNOWN
# 310               (            -1          PUNCT  VOICE_UNKNOWN
# 311            $1.2            -1            NUM  VOICE_UNKNOWN
# 312         billion            -1            NUM  VOICE_UNKNOWN
# 313               )            -1          PUNCT  VOICE_UNKNOWN
# 314         through            -1            ADP  VOICE_UNKNOWN
# 315             the            -1            DET  VOICE_UNKNOWN
# 316        alliance            -1           NOUN  VOICE_UNKNOWN
# 317               ,            -1          PUNCT  VOICE_UNKNOWN
# 318       Bloomberg            -1           NOUN  VOICE_UNKNOWN
# 319            News            -1           NOUN  VOICE_UNKNOWN
# 320      previously            -1            ADV  VOICE_UNKNOWN
# 321        reported            -1           VERB  VOICE_UNKNOWN
# 322               .            -1          PUNCT  VOICE_UNKNOWN
# 323        Alphabet            -1           NOUN  VOICE_UNKNOWN
# 324            last            -1            ADJ  VOICE_UNKNOWN
# 325           month            -1           NOUN  VOICE_UNKNOWN
# 326        unveiled            -1           VERB  VOICE_UNKNOWN
# 327              an            -1            DET  VOICE_UNKNOWN
# 328       expansion            -1           NOUN  VOICE_UNKNOWN
# 329              of            -1            ADP  VOICE_UNKNOWN
# 330          Google            -1           NOUN  VOICE_UNKNOWN
# 331             Pay            -1           NOUN  VOICE_UNKNOWN
# 332               ,            -1          PUNCT  VOICE_UNKNOWN
# 333      partnering            -1           VERB  VOICE_UNKNOWN
# 334            with            -1            ADP  VOICE_UNKNOWN
# 335           banks            -1           NOUN  VOICE_UNKNOWN
# 336             and            -1           CONJ  VOICE_UNKNOWN
# 337       retailers            -1           NOUN  VOICE_UNKNOWN
# 338              in            -1            ADP  VOICE_UNKNOWN
# 339             the            -1            DET  VOICE_UNKNOWN
# 340            U.S.            -1           NOUN  VOICE_UNKNOWN
# 341              to            -1            PRT  VOICE_UNKNOWN
# 342           offer            -1           VERB  VOICE_UNKNOWN
# 343       consumers            -1           NOUN  VOICE_UNKNOWN
# 344             new            -1            ADJ  VOICE_UNKNOWN
# 345           forms            -1           NOUN  VOICE_UNKNOWN
# 346              of            -1            ADP  VOICE_UNKNOWN
# 347            bank            -1           NOUN  VOICE_UNKNOWN
# 348        accounts            -1           NOUN  VOICE_UNKNOWN
# 349               ,            -1          PUNCT  VOICE_UNKNOWN
# 350           cards            -1           NOUN  VOICE_UNKNOWN
# 351             and            -1           CONJ  VOICE_UNKNOWN
# 352       discounts            -1           NOUN  VOICE_UNKNOWN
# 353               .            -1          PUNCT  VOICE_UNKNOWN
# 354             The            -1            DET  VOICE_UNKNOWN
# 355        upgraded            -1           VERB  VOICE_UNKNOWN
# 356         payment            -1           NOUN  VOICE_UNKNOWN
# 357          system            -1           NOUN  VOICE_UNKNOWN
# 358           marks            -1           VERB  VOICE_UNKNOWN
# 359             the            -1            DET  VOICE_UNKNOWN
# 360            tech            -1           NOUN  VOICE_UNKNOWN
# 361           giant            -1           NOUN  VOICE_UNKNOWN
# 362              ’s            -1            PRT  VOICE_UNKNOWN
# 363         deepest            -1            ADJ  VOICE_UNKNOWN
# 364           foray            -1           NOUN  VOICE_UNKNOWN
# 365             yet            -1            ADV  VOICE_UNKNOWN
# 366            into            -1            ADP  VOICE_UNKNOWN
# 367             the            -1            DET  VOICE_UNKNOWN
# 368            U.S.            -1           NOUN  VOICE_UNKNOWN
# 369       financial            -1            ADJ  VOICE_UNKNOWN
# 370          system            -1           NOUN  VOICE_UNKNOWN
# 371               .            -1          PUNCT  VOICE_UNKNOWN
# 372             For            -1            ADP  VOICE_UNKNOWN
# 373            more            -1            ADJ  VOICE_UNKNOWN
# 374        articles            -1           NOUN  VOICE_UNKNOWN
# 375            like            -1            ADP  VOICE_UNKNOWN
# 376            this            -1            DET  VOICE_UNKNOWN
# 377               ,            -1          PUNCT  VOICE_UNKNOWN
# 378          please            -1              X  VOICE_UNKNOWN
# 379           visit            -1           VERB  VOICE_UNKNOWN
# 380              us            -1           PRON  VOICE_UNKNOWN
# 381              at            -1            ADP  VOICE_UNKNOWN
# 382   bloomberg.com            -1              X  VOICE_UNKNOWN
# 383               ©            -1            NUM  VOICE_UNKNOWN
# 384            2020            -1            NUM  VOICE_UNKNOWN
# 385       Bloomberg            -1           NOUN  VOICE_UNKNOWN
# 386            L.P.            -1           NOUN  VOICE_UNKNOWN
# 387               ©            -1            NUM  VOICE_UNKNOWN
# 388            2020            -1            NUM  VOICE_UNKNOWN
# 389       Bloomberg            -1           NOUN  VOICE_UNKNOWN
# 390            L.P.            -1           NOUN  VOICE_UNKNOWN
#
#              Tense          Lemma  index      Label
# 0    TENSE_UNKNOWN       Deutsche      1         NN
# 1    TENSE_UNKNOWN           Bank      1       ROOT
# 2    TENSE_UNKNOWN             to      3        AUX
# 3    TENSE_UNKNOWN           Move      1       VMOD
# 4    TENSE_UNKNOWN              ‘      5          P
# 5    TENSE_UNKNOWN          Heart      3       DOBJ
# 6    TENSE_UNKNOWN              ’      5          P
# 7    TENSE_UNKNOWN             of      5       PREP
# 8    TENSE_UNKNOWN             IT      9         NN
# 9    TENSE_UNKNOWN         system      7       POBJ
# 10   TENSE_UNKNOWN           Into     30       MARK
# 11   TENSE_UNKNOWN         Google     15       POSS
# 12   TENSE_UNKNOWN             ’s     11         PS
# 13   TENSE_UNKNOWN          Cloud     15         NN
# 14   TENSE_UNKNOWN         Steven     15         NN
# 15   TENSE_UNKNOWN          Arons     30      NSUBJ
# 16   TENSE_UNKNOWN            and     15         CC
# 17   TENSE_UNKNOWN           Nico     19         NN
# 18   TENSE_UNKNOWN          Grant     19         NN
# 19   TENSE_UNKNOWN       December     15       CONJ
# 20   TENSE_UNKNOWN              4     19        NUM
# 21   TENSE_UNKNOWN              ,     19          P
# 22   TENSE_UNKNOWN           2020     19       TMOD
# 23   TENSE_UNKNOWN              (     19          P
# 24   TENSE_UNKNOWN      Bloomberg     19      APPOS
# 25   TENSE_UNKNOWN              )     19          P
# 26   TENSE_UNKNOWN             --     15          P
# 27   TENSE_UNKNOWN       Deutsche     29         NN
# 28   TENSE_UNKNOWN           Bank     29         NN
# 29   TENSE_UNKNOWN             AG     15      APPOS
# 30         PRESENT         expect      3      ADVCL
# 31   TENSE_UNKNOWN             to     33        AUX
# 32   TENSE_UNKNOWN     ultimately     33     ADVMOD
# 33   TENSE_UNKNOWN        replace     30      XCOMP
# 34   TENSE_UNKNOWN          large     35       AMOD
# 35   TENSE_UNKNOWN           part     33       DOBJ
# 36   TENSE_UNKNOWN             of     35       PREP
# 37   TENSE_UNKNOWN            its     40       POSS
# 38   TENSE_UNKNOWN           core     40         NN
# 39   TENSE_UNKNOWN        banking     40         NN
# 40   TENSE_UNKNOWN         system     36       POBJ
# 41   TENSE_UNKNOWN           with     33       PREP
# 42   TENSE_UNKNOWN    alternative     41       POBJ
# 43            PAST          power     42       VMOD
# 44   TENSE_UNKNOWN             by     43       PREP
# 45   TENSE_UNKNOWN       Alphabet     48       POSS
# 46   TENSE_UNKNOWN           Inc.     45     SUFFIX
# 47   TENSE_UNKNOWN             ’s     45         PS
# 48   TENSE_UNKNOWN         Google     44       POBJ
# 49   TENSE_UNKNOWN              ,     33          P
# 50   TENSE_UNKNOWN             as     54       MARK
# 51   TENSE_UNKNOWN            the     53        DET
# 52   TENSE_UNKNOWN         German     53       AMOD
# 53   TENSE_UNKNOWN         lender     54      NSUBJ
# 54         PRESENT         embark     33      ADVCL
# 55   TENSE_UNKNOWN             on     54       PREP
# 56   TENSE_UNKNOWN            its     58       POSS
# 57   TENSE_UNKNOWN            big     58       AMOD
# 58   TENSE_UNKNOWN         effort     55       POBJ
# 59   TENSE_UNKNOWN            yet     54     ADVMOD
# 60   TENSE_UNKNOWN             to     61        AUX
# 61   TENSE_UNKNOWN      modernize     54      XCOMP
# 62   TENSE_UNKNOWN       computer     63         NN
# 63   TENSE_UNKNOWN         system     61       DOBJ
# 64   TENSE_UNKNOWN           that     66      NSUBJ
# 65         PRESENT           have     66        AUX
# 66            PAST         hamper     63      RCMOD
# 67   TENSE_UNKNOWN             it     66       DOBJ
# 68   TENSE_UNKNOWN            for     66       PREP
# 69   TENSE_UNKNOWN           year     68       POBJ
# 70   TENSE_UNKNOWN              .      1          P
# 71   TENSE_UNKNOWN            The     73        DET
# 72   TENSE_UNKNOWN            two     73        NUM
# 73   TENSE_UNKNOWN        company     76      NSUBJ
# 74   TENSE_UNKNOWN             on     73       PREP
# 75   TENSE_UNKNOWN         Friday     74       POBJ
# 76            PAST       finalize    101      CCOMP
# 77   TENSE_UNKNOWN              a     80        DET
# 78   TENSE_UNKNOWN          cloud     79         NN
# 79   TENSE_UNKNOWN      computing     80         NN
# 80   TENSE_UNKNOWN      agreement     76       DOBJ
# 81   TENSE_UNKNOWN          under     86       PREP
# 82   TENSE_UNKNOWN          which     81       POBJ
# 83   TENSE_UNKNOWN            the     85        DET
# 84   TENSE_UNKNOWN         German     85       AMOD
# 85   TENSE_UNKNOWN         lender     86      NSUBJ
# 86         PRESENT           plan     80      RCMOD
# 87   TENSE_UNKNOWN             to     88        AUX
# 88   TENSE_UNKNOWN          shift     86      XCOMP
# 89   TENSE_UNKNOWN           most     88       DOBJ
# 90   TENSE_UNKNOWN             of     89       PREP
# 91   TENSE_UNKNOWN            its     92       POSS
# 92   TENSE_UNKNOWN           data     90       POBJ
# 93   TENSE_UNKNOWN           onto     88       PREP
# 94   TENSE_UNKNOWN         Google     95         NN
# 95   TENSE_UNKNOWN         server     93       POBJ
# 96   TENSE_UNKNOWN              ,    101          P
# 97   TENSE_UNKNOWN     technology     98         NN
# 98   TENSE_UNKNOWN           head    100         NN
# 99   TENSE_UNKNOWN          Bernd    100         NN
# 100  TENSE_UNKNOWN        Leukert    101      NSUBJ
# 101           PAST            say    101       ROOT
# 102  TENSE_UNKNOWN             in    101       PREP
# 103  TENSE_UNKNOWN              a    105        DET
# 104  TENSE_UNKNOWN          phone    105         NN
# 105  TENSE_UNKNOWN      interview    102       POBJ
# 106  TENSE_UNKNOWN              .    101          P
# 107  TENSE_UNKNOWN           Both    108        DET
# 108  TENSE_UNKNOWN           firm    110      NSUBJ
# 109  TENSE_UNKNOWN           also    110     ADVMOD
# 110           PAST          agree    110       ROOT
# 111  TENSE_UNKNOWN             to    113        AUX
# 112  TENSE_UNKNOWN        jointly    113     ADVMOD
# 113  TENSE_UNKNOWN        develop    110      XCOMP
# 114  TENSE_UNKNOWN        product    113       DOBJ
# 115  TENSE_UNKNOWN        include    114       PREP
# 116  TENSE_UNKNOWN            new    118       AMOD
# 117  TENSE_UNKNOWN        lending    118         NN
# 118  TENSE_UNKNOWN       offering    115       POBJ
# 119  TENSE_UNKNOWN            and    118         CC
# 120  TENSE_UNKNOWN         retail    121       AMOD
# 121  TENSE_UNKNOWN            app    118       CONJ
# 122  TENSE_UNKNOWN              .    110          P
# 123  TENSE_UNKNOWN            The    124        DET
# 124  TENSE_UNKNOWN           deal    126      NSUBJ
# 125  TENSE_UNKNOWN           will    126        AUX
# 126  TENSE_UNKNOWN        include    138      CCOMP
# 127  TENSE_UNKNOWN              “    126          P
# 128  TENSE_UNKNOWN    application    126       DOBJ
# 129  TENSE_UNKNOWN             at    128       PREP
# 130  TENSE_UNKNOWN            the    131        DET
# 131  TENSE_UNKNOWN          heart    129       POBJ
# 132  TENSE_UNKNOWN             of    131       PREP
# 133  TENSE_UNKNOWN            our    134       POSS
# 134  TENSE_UNKNOWN             IT    132       POBJ
# 135  TENSE_UNKNOWN              ,    138          P
# 136  TENSE_UNKNOWN              ”    138          P
# 137  TENSE_UNKNOWN        Leukert    138      NSUBJ
# 138           PAST            say    138       ROOT
# 139  TENSE_UNKNOWN             in    138       PREP
# 140  TENSE_UNKNOWN             an    141        DET
# 141  TENSE_UNKNOWN      interview    139       POBJ
# 142  TENSE_UNKNOWN              ,    138          P
# 143  TENSE_UNKNOWN            add    138      XCOMP
# 144  TENSE_UNKNOWN           that    149       MARK
# 145  TENSE_UNKNOWN           only    147     ADVMOD
# 146  TENSE_UNKNOWN       Deutsche    147         NN
# 147  TENSE_UNKNOWN           Bank    149      NSUBJ
# 148  TENSE_UNKNOWN           will    149        AUX
# 149  TENSE_UNKNOWN           have    143      CCOMP
# 150  TENSE_UNKNOWN            the    151        DET
# 151  TENSE_UNKNOWN            key    149       DOBJ
# 152  TENSE_UNKNOWN             to    153        AUX
# 153  TENSE_UNKNOWN        decrypt    151       VMOD
# 154  TENSE_UNKNOWN           data    153       DOBJ
# 155  TENSE_UNKNOWN             it    156      NSUBJ
# 156        PRESENT       transfer    154      RCMOD
# 157  TENSE_UNKNOWN             to    156       PREP
# 158  TENSE_UNKNOWN            the    159        DET
# 159  TENSE_UNKNOWN          cloud    157       POBJ
# 160  TENSE_UNKNOWN              .    138          P
# 161  TENSE_UNKNOWN            cut    168      CSUBJ
# 162  TENSE_UNKNOWN           cost    161       DOBJ
# 163  TENSE_UNKNOWN        through    161       PREP
# 164  TENSE_UNKNOWN     automation    163       POBJ
# 165  TENSE_UNKNOWN            and    164         CC
# 166  TENSE_UNKNOWN           good    167       AMOD
# 167  TENSE_UNKNOWN     technology    164       CONJ
# 168        PRESENT             be    168       ROOT
# 169  TENSE_UNKNOWN              a    170        DET
# 170  TENSE_UNKNOWN    centerpiece    168       ATTR
# 171  TENSE_UNKNOWN             of    170       PREP
# 172  TENSE_UNKNOWN            the    174        DET
# 173  TENSE_UNKNOWN     turnaround    174         NN
# 174  TENSE_UNKNOWN           plan    171       POBJ
# 175           PAST         unveil    174       VMOD
# 176  TENSE_UNKNOWN             by    175       PREP
# 177  TENSE_UNKNOWN          Chief    178         NN
# 178  TENSE_UNKNOWN      Executive    179      TITLE
# 179  TENSE_UNKNOWN        Officer    181      TITLE
# 180  TENSE_UNKNOWN      Christian    181         NN
# 181  TENSE_UNKNOWN         Sewing    176       POBJ
# 182  TENSE_UNKNOWN           last    183       AMOD
# 183  TENSE_UNKNOWN           year    175       TMOD
# 184  TENSE_UNKNOWN              .    168          P
# 185  TENSE_UNKNOWN            For    190       PREP
# 186  TENSE_UNKNOWN         Google    185       POBJ
# 187  TENSE_UNKNOWN              ,    190          P
# 188  TENSE_UNKNOWN            the    189        DET
# 189  TENSE_UNKNOWN           deal    190      NSUBJ
# 190        PRESENT             be    190       ROOT
# 191  TENSE_UNKNOWN              a    192        DET
# 192  TENSE_UNKNOWN           step    190       ATTR
# 193  TENSE_UNKNOWN         toward    192       PREP
# 194  TENSE_UNKNOWN          break    193      PCOMP
# 195  TENSE_UNKNOWN           into    194       PREP
# 196  TENSE_UNKNOWN            the    199        DET
# 197  TENSE_UNKNOWN           grow    199       AMOD
# 198  TENSE_UNKNOWN          cloud    199         NN
# 199  TENSE_UNKNOWN       business    195       POBJ
# 200  TENSE_UNKNOWN           with    194       PREP
# 201  TENSE_UNKNOWN       European    202       AMOD
# 202  TENSE_UNKNOWN           bank    200       POBJ
# 203  TENSE_UNKNOWN              .    190          P
# 204  TENSE_UNKNOWN            The    205        DET
# 205  TENSE_UNKNOWN       business    208  NSUBJPASS
# 206        PRESENT             be    208    AUXPASS
# 207  TENSE_UNKNOWN      currently    208     ADVMOD
# 208           PAST       dominate    223      CCOMP
# 209  TENSE_UNKNOWN             by    208       PREP
# 210  TENSE_UNKNOWN      Microsoft    209       POBJ
# 211  TENSE_UNKNOWN          Corp.    210     SUFFIX
# 212  TENSE_UNKNOWN            and    210         CC
# 213  TENSE_UNKNOWN     Amazon.com    210       CONJ
# 214  TENSE_UNKNOWN           Inc.    213     SUFFIX
# 215  TENSE_UNKNOWN              ,    213          P
# 216  TENSE_UNKNOWN              a    219        DET
# 217  TENSE_UNKNOWN      Bloomberg    218         NN
# 218  TENSE_UNKNOWN           News    219         NN
# 219  TENSE_UNKNOWN       analysis    213      APPOS
# 220  TENSE_UNKNOWN        earlier    222     ADVMOD
# 221  TENSE_UNKNOWN           this    222        DET
# 222  TENSE_UNKNOWN           year    219       TMOD
# 223           PAST           show    223       ROOT
# 224  TENSE_UNKNOWN              .    223          P
# 225  TENSE_UNKNOWN        Exactly    227     ADVMOD
# 226  TENSE_UNKNOWN            how    227     ADVMOD
# 227  TENSE_UNKNOWN           much    234     ADVMOD
# 228  TENSE_UNKNOWN             of    227       PREP
# 229  TENSE_UNKNOWN            its    230       POSS
# 230  TENSE_UNKNOWN         system    228       POBJ
# 231  TENSE_UNKNOWN       Deutsche    232         NN
# 232  TENSE_UNKNOWN           Bank    234      NSUBJ
# 233  TENSE_UNKNOWN           will    234        AUX
# 234  TENSE_UNKNOWN           move    240      CSUBJ
# 235  TENSE_UNKNOWN           into    234       PREP
# 236  TENSE_UNKNOWN         Google    238       POSS
# 237  TENSE_UNKNOWN             ’s    236         PS
# 238  TENSE_UNKNOWN          cloud    235       POBJ
# 239  TENSE_UNKNOWN           will    240        AUX
# 240  TENSE_UNKNOWN         depend    253      CCOMP
# 241  TENSE_UNKNOWN             on    240       PREP
# 242  TENSE_UNKNOWN              “    241          P
# 243  TENSE_UNKNOWN          legal    249       AMOD
# 244  TENSE_UNKNOWN              ,    243          P
# 245  TENSE_UNKNOWN     regulatory    243       CONJ
# 246  TENSE_UNKNOWN            and    243         CC
# 247  TENSE_UNKNOWN           data    243       CONJ
# 248  TENSE_UNKNOWN        privacy    249         NN
# 249  TENSE_UNKNOWN  consideration    241       POBJ
# 250  TENSE_UNKNOWN              ,    253          P
# 251  TENSE_UNKNOWN              ”    253          P
# 252  TENSE_UNKNOWN        Leukert    253      NSUBJ
# 253           PAST            say    253       ROOT
# 254  TENSE_UNKNOWN              .    253          P
# 255  TENSE_UNKNOWN            The    257        DET
# 256  TENSE_UNKNOWN            two    257        NUM
# 257  TENSE_UNKNOWN        company    258      NSUBJ
# 258        PRESENT         expect    283      CCOMP
# 259  TENSE_UNKNOWN             to    260        AUX
# 260  TENSE_UNKNOWN           sell    258      XCOMP
# 261  TENSE_UNKNOWN           some    262        DET
# 262  TENSE_UNKNOWN     technology    260       DOBJ
# 263  TENSE_UNKNOWN           that    265       DOBJ
# 264  TENSE_UNKNOWN           they    265      NSUBJ
# 265        PRESENT        develop    262      RCMOD
# 266  TENSE_UNKNOWN       together    265     ADVMOD
# 267  TENSE_UNKNOWN             to    265       PREP
# 268  TENSE_UNKNOWN          other    271       AMOD
# 269  TENSE_UNKNOWN      financial    270       AMOD
# 270  TENSE_UNKNOWN        service    271         NN
# 271  TENSE_UNKNOWN       provider    267       POBJ
# 272  TENSE_UNKNOWN             as    271       PREP
# 273  TENSE_UNKNOWN          white    275       AMOD
# 274  TENSE_UNKNOWN              -    275          P
# 275  TENSE_UNKNOWN          label    276         NN
# 276  TENSE_UNKNOWN        product    272       POBJ
# 277  TENSE_UNKNOWN            and    265         CC
# 278           PAST          split    265       CONJ
# 279  TENSE_UNKNOWN            the    280        DET
# 280  TENSE_UNKNOWN        revenue    278       DOBJ
# 281  TENSE_UNKNOWN              ,    283          P
# 282  TENSE_UNKNOWN             he    283      NSUBJ
# 283           PAST            say    283       ROOT
# 284  TENSE_UNKNOWN              .    283          P
# 285  TENSE_UNKNOWN            The    286        DET
# 286  TENSE_UNKNOWN       contract    288  NSUBJPASS
# 287        PRESENT             be    288    AUXPASS
# 288           PAST            set    321      CCOMP
# 289  TENSE_UNKNOWN             to    290        AUX
# 290  TENSE_UNKNOWN           last    288      XCOMP
# 291  TENSE_UNKNOWN             at    292     ADVMOD
# 292  TENSE_UNKNOWN          least    293     ADVMOD
# 293  TENSE_UNKNOWN             10    294        NUM
# 294  TENSE_UNKNOWN           year    290       TMOD
# 295  TENSE_UNKNOWN            and    288         CC
# 296  TENSE_UNKNOWN       Deutsche    297         NN
# 297  TENSE_UNKNOWN           Bank    298      NSUBJ
# 298        PRESENT         expect    288       CONJ
# 299  TENSE_UNKNOWN             to    300        AUX
# 300  TENSE_UNKNOWN           make    298      XCOMP
# 301  TENSE_UNKNOWN              a    303        DET
# 302  TENSE_UNKNOWN     cumulative    303       AMOD
# 303  TENSE_UNKNOWN         return    300       DOBJ
# 304  TENSE_UNKNOWN             on    303       PREP
# 305  TENSE_UNKNOWN     investment    304       POBJ
# 306  TENSE_UNKNOWN             of    305       PREP
# 307  TENSE_UNKNOWN              1    308     NUMBER
# 308  TENSE_UNKNOWN        billion    309        NUM
# 309  TENSE_UNKNOWN           euro    306       POBJ
# 310  TENSE_UNKNOWN              (    309          P
# 311  TENSE_UNKNOWN           $1.2    312        NUM
# 312  TENSE_UNKNOWN        billion    309      APPOS
# 313  TENSE_UNKNOWN              )    309          P
# 314  TENSE_UNKNOWN        through    305       PREP
# 315  TENSE_UNKNOWN            the    316        DET
# 316  TENSE_UNKNOWN       alliance    314       POBJ
# 317  TENSE_UNKNOWN              ,    321          P
# 318  TENSE_UNKNOWN      Bloomberg    319         NN
# 319  TENSE_UNKNOWN           News    321      NSUBJ
# 320  TENSE_UNKNOWN     previously    321     ADVMOD
# 321           PAST         report    321       ROOT
# 322  TENSE_UNKNOWN              .    321          P
# 323  TENSE_UNKNOWN       Alphabet    326      NSUBJ
# 324  TENSE_UNKNOWN           last    325       AMOD
# 325  TENSE_UNKNOWN          month    326       TMOD
# 326           PAST         unveil    326       ROOT
# 327  TENSE_UNKNOWN             an    328        DET
# 328  TENSE_UNKNOWN      expansion    326       DOBJ
# 329  TENSE_UNKNOWN             of    328       PREP
# 330  TENSE_UNKNOWN         Google    331         NN
# 331  TENSE_UNKNOWN            Pay    329       POBJ
# 332  TENSE_UNKNOWN              ,    326          P
# 333  TENSE_UNKNOWN        partner    326       VMOD
# 334  TENSE_UNKNOWN           with    333       PREP
# 335  TENSE_UNKNOWN           bank    334       POBJ
# 336  TENSE_UNKNOWN            and    335         CC
# 337  TENSE_UNKNOWN       retailer    335       CONJ
# 338  TENSE_UNKNOWN             in    335       PREP
# 339  TENSE_UNKNOWN            the    340        DET
# 340  TENSE_UNKNOWN           U.S.    338       POBJ
# 341  TENSE_UNKNOWN             to    342        AUX
# 342  TENSE_UNKNOWN          offer    333      XCOMP
# 343  TENSE_UNKNOWN       consumer    342       IOBJ
# 344  TENSE_UNKNOWN            new    345       AMOD
# 345  TENSE_UNKNOWN           form    342       DOBJ
# 346  TENSE_UNKNOWN             of    345       PREP
# 347  TENSE_UNKNOWN           bank    348         NN
# 348  TENSE_UNKNOWN        account    346       POBJ
# 349  TENSE_UNKNOWN              ,    348          P
# 350  TENSE_UNKNOWN           card    348       CONJ
# 351  TENSE_UNKNOWN            and    348         CC
# 352  TENSE_UNKNOWN       discount    348       CONJ
# 353  TENSE_UNKNOWN              .    326          P
# 354  TENSE_UNKNOWN            The    357        DET
# 355           PAST        upgrade    357       AMOD
# 356  TENSE_UNKNOWN        payment    357         NN
# 357  TENSE_UNKNOWN         system    358      NSUBJ
# 358        PRESENT           mark    358       ROOT
# 359  TENSE_UNKNOWN            the    361        DET
# 360  TENSE_UNKNOWN           tech    361         NN
# 361  TENSE_UNKNOWN          giant    364       POSS
# 362  TENSE_UNKNOWN             ’s    361         PS
# 363  TENSE_UNKNOWN           deep    364       AMOD
# 364  TENSE_UNKNOWN          foray    358       DOBJ
# 365  TENSE_UNKNOWN            yet    358     ADVMOD
# 366  TENSE_UNKNOWN           into    358       PREP
# 367  TENSE_UNKNOWN            the    370        DET
# 368  TENSE_UNKNOWN           U.S.    370         NN
# 369  TENSE_UNKNOWN      financial    370       AMOD
# 370  TENSE_UNKNOWN         system    366       POBJ
# 371  TENSE_UNKNOWN              .    358          P
# 372  TENSE_UNKNOWN            For    379       PREP
# 373  TENSE_UNKNOWN           more    374       AMOD
# 374  TENSE_UNKNOWN        article    372       POBJ
# 375  TENSE_UNKNOWN           like    374       PREP
# 376  TENSE_UNKNOWN           this    375       POBJ
# 377  TENSE_UNKNOWN              ,    379          P
# 378  TENSE_UNKNOWN         please    379  DISCOURSE
# 379  TENSE_UNKNOWN          visit    379       ROOT
# 380  TENSE_UNKNOWN             us    379       DOBJ
# 381  TENSE_UNKNOWN             at    379       PREP
# 382  TENSE_UNKNOWN  bloomberg.com    383        DEP
# 383  TENSE_UNKNOWN              ©    381       POBJ
# 384  TENSE_UNKNOWN           2020    386        NUM
# 385  TENSE_UNKNOWN      Bloomberg    386         NN
# 386  TENSE_UNKNOWN           L.P.    383        DEP
# 387  TENSE_UNKNOWN              ©    383        DEP
# 388  TENSE_UNKNOWN           2020    390        NUM
# 389  TENSE_UNKNOWN      Bloomberg    390         NN
# 390  TENSE_UNKNOWN           L.P.    383      APPOS

# %% [markdown]
# #### Analyze Entities
# Entity Analysis inspects the given text for known entities (proper nouns such as public figures, landmarks, etc.), and returns information about those entities.

# %%
entities=gcp_analyze_entities(text)
df_entities = pd.DataFrame(entities)
df_entities
# Out:
#                            name           type  Salience            mid  \
# 0                 Deutsche Bank   ORGANIZATION  0.112376      /m/02lc8s
# 1                        Google   ORGANIZATION  0.111964      /m/045c7b
# 2                        lender   ORGANIZATION  0.111934            NaN
# 3           core banking system          OTHER  0.049610            NaN
# 4                    IT Systems          OTHER  0.049610            NaN
# 5              computer systems          OTHER  0.047956            NaN
# 6                         Heart          OTHER  0.038004            NaN
# 7                         parts       LOCATION  0.033440            NaN
# 8                  alternatives          OTHER  0.033440            NaN
# 9                     Bloomberg   ORGANIZATION  0.028145      /m/027sm6
# 10                         deal          OTHER  0.024407            NaN
# 11                Alphabet Inc.   ORGANIZATION  0.022594  /g/11bwcf511s
# 12                   Nico Grant         PERSON  0.019865  /g/11f0x8h214
# 13    cloud computing agreement          OTHER  0.015600            NaN
# 14           Cloud Steven Arons         PERSON  0.014812            NaN
# 15                       effort          OTHER  0.012746            NaN
# 16                Bernd Leukert         PERSON  0.009743  /g/11fy1t_1kz
# 17                       German       LOCATION  0.009697            NaN
# 18                    companies   ORGANIZATION  0.008209            NaN
# 19                         data          OTHER  0.007645            NaN
# 20                      servers          OTHER  0.006974            NaN
# 21                        banks   ORGANIZATION  0.006337            NaN
# 22                         most          OTHER  0.006127            NaN
# 23                    companies   ORGANIZATION  0.006090            NaN
# 24                        cloud          OTHER  0.005896            NaN
# 25                      systems          OTHER  0.005635            NaN
# 26                   technology          OTHER  0.005547            NaN
# 27                         deal          OTHER  0.005408            NaN
# 28                        cloud          OTHER  0.005364            NaN
# 29                  centerpiece          OTHER  0.005227            NaN
# 30                         data          OTHER  0.005179            NaN
# 31                        banks   ORGANIZATION  0.004741            NaN
# 32              phone interview          OTHER  0.004706            NaN
# 33                     products  CONSUMER_GOOD  0.004683            NaN
# 34                    interview          EVENT  0.004666            NaN
# 35                           IT          OTHER  0.004666            NaN
# 36                        heart          OTHER  0.004666            NaN
# 37               cloud business          OTHER  0.004313            NaN
# 38                     business          OTHER  0.004305            NaN
# 39                   technology          OTHER  0.004264            NaN
# 40                        costs          OTHER  0.004138            NaN
# 41              turnaround plan          OTHER  0.004138            NaN
# 42                   automation          OTHER  0.004138            NaN
# 43      Chief Executive Officer         PERSON  0.004138            NaN
# 44                         apps  CONSUMER_GOOD  0.004114            NaN
# 45                        firms   ORGANIZATION  0.004114            NaN
# 46                          key          OTHER  0.004099            NaN
# 47                 applications          OTHER  0.004099            NaN
# 48                     analysis          OTHER  0.003781            NaN
# 49                         much          OTHER  0.003775            NaN
# 50               Bloomberg News   ORGANIZATION  0.003250      /m/06b75n
# 51                       system          OTHER  0.002958            NaN
# 52               payment system          OTHER  0.002958            NaN
# 53                   investment          OTHER  0.002837            NaN
# 54                     alliance          OTHER  0.002837            NaN
# 55                    retailers   ORGANIZATION  0.002834            NaN
# 56                    expansion          OTHER  0.002834            NaN
# 57            lending offerings          OTHER  0.002741            NaN
# 58             Christian Sewing   ORGANIZATION  0.002446  /g/11f5ckrc2p
# 59                    consumers         PERSON  0.002258            NaN
# 60                       return          OTHER  0.002246            NaN
# 61                     European       LOCATION  0.002239            NaN
# 62              Amazon.com Inc.   ORGANIZATION  0.002235       /m/0mgkg
# 63              Microsoft Corp.   ORGANIZATION  0.002235       /m/04sv4
# 64                        foray          OTHER  0.002056            NaN
# 65                    discounts          OTHER  0.001983            NaN
# 66                        cards          OTHER  0.001983            NaN
# 67                bank accounts          OTHER  0.001983            NaN
# 68                   tech giant   ORGANIZATION  0.001981            NaN
# 69                     articles    WORK_OF_ART  0.001979            NaN
# 70                        forms          OTHER  0.001935            NaN
# 71                     Alphabet          OTHER  0.001907        /m/0hwf
# 72                         U.S.       LOCATION  0.001684      /m/09c7w0
# 73                   Google Pay          OTHER  0.001675  /g/11b7dtvvwt
# 74  data privacy considerations          OTHER  0.001420            NaN
# 75                     products  CONSUMER_GOOD  0.001418            NaN
# 76                     services          OTHER  0.001418            NaN
# 77                     contract          OTHER  0.001407            NaN
# 78                      revenue          OTHER  0.001245            NaN
# 79                    providers   ORGANIZATION  0.001245            NaN
# 80             December 4, 2020           DATE  0.000000            NaN
# 81                         2020           DATE  0.000000            NaN
# 82                         2020           DATE  0.000000            NaN
# 83              1 billion euros          PRICE  0.000000            NaN
# 84                 $1.2 billion          PRICE  0.000000            NaN
# 85                         2020         NUMBER  0.000000            NaN
# 86                    1 billion         NUMBER  0.000000            NaN
# 87                          two         NUMBER  0.000000            NaN
# 88                         2020         NUMBER  0.000000            NaN
# 89                         2020         NUMBER  0.000000            NaN
# 90                  1.2 billion         NUMBER  0.000000            NaN
# 91                           10         NUMBER  0.000000            NaN
# 92                            4         NUMBER  0.000000            NaN
# 93                          two         NUMBER  0.000000            NaN
#
#                                         wikipedia_url month  day  year  \
# 0         https://en.wikipedia.org/wiki/Deutsche_Bank   NaN  NaN   NaN
# 1                https://en.wikipedia.org/wiki/Google   NaN  NaN   NaN
# 2                                                 NaN   NaN  NaN   NaN
# 3                                                 NaN   NaN  NaN   NaN
# 4                                                 NaN   NaN  NaN   NaN
# 5                                                 NaN   NaN  NaN   NaN
# 6                                                 NaN   NaN  NaN   NaN
# 7                                                 NaN   NaN  NaN   NaN
# 8                                                 NaN   NaN  NaN   NaN
# 9        https://en.wikipedia.org/wiki/Bloomberg_L.P.   NaN  NaN   NaN
# 10                                                NaN   NaN  NaN   NaN
# 11        https://en.wikipedia.org/wiki/Alphabet_Inc.   NaN  NaN   NaN
# 12                                                NaN   NaN  NaN   NaN
# 13                                                NaN   NaN  NaN   NaN
# 14                                                NaN   NaN  NaN   NaN
# 15                                                NaN   NaN  NaN   NaN
# 16        https://de.wikipedia.org/wiki/Bernd_Leukert   NaN  NaN   NaN
# 17                                                NaN   NaN  NaN   NaN
# 18                                                NaN   NaN  NaN   NaN
# 19                                                NaN   NaN  NaN   NaN
# 20                                                NaN   NaN  NaN   NaN
# 21                                                NaN   NaN  NaN   NaN
# 22                                                NaN   NaN  NaN   NaN
# 23                                                NaN   NaN  NaN   NaN
# 24                                                NaN   NaN  NaN   NaN
# 25                                                NaN   NaN  NaN   NaN
# 26                                                NaN   NaN  NaN   NaN
# 27                                                NaN   NaN  NaN   NaN
# 28                                                NaN   NaN  NaN   NaN
# 29                                                NaN   NaN  NaN   NaN
# 30                                                NaN   NaN  NaN   NaN
# 31                                                NaN   NaN  NaN   NaN
# 32                                                NaN   NaN  NaN   NaN
# 33                                                NaN   NaN  NaN   NaN
# 34                                                NaN   NaN  NaN   NaN
# 35                                                NaN   NaN  NaN   NaN
# 36                                                NaN   NaN  NaN   NaN
# 37                                                NaN   NaN  NaN   NaN
# 38                                                NaN   NaN  NaN   NaN
# 39                                                NaN   NaN  NaN   NaN
# 40                                                NaN   NaN  NaN   NaN
# 41                                                NaN   NaN  NaN   NaN
# 42                                                NaN   NaN  NaN   NaN
# 43                                                NaN   NaN  NaN   NaN
# 44                                                NaN   NaN  NaN   NaN
# 45                                                NaN   NaN  NaN   NaN
# 46                                                NaN   NaN  NaN   NaN
# 47                                                NaN   NaN  NaN   NaN
# 48                                                NaN   NaN  NaN   NaN
# 49                                                NaN   NaN  NaN   NaN
# 50  https://en.wikipedia.org/wiki/Bloomberg_Televi...   NaN  NaN   NaN
# 51                                                NaN   NaN  NaN   NaN
# 52                                                NaN   NaN  NaN   NaN
# 53                                                NaN   NaN  NaN   NaN
# 54                                                NaN   NaN  NaN   NaN
# 55                                                NaN   NaN  NaN   NaN
# 56                                                NaN   NaN  NaN   NaN
# 57                                                NaN   NaN  NaN   NaN
# 58     https://en.wikipedia.org/wiki/Christian_Sewing   NaN  NaN   NaN
# 59                                                NaN   NaN  NaN   NaN
# 60                                                NaN   NaN  NaN   NaN
# 61                                                NaN   NaN  NaN   NaN
# 62     https://en.wikipedia.org/wiki/Amazon_(company)   NaN  NaN   NaN
# 63            https://en.wikipedia.org/wiki/Microsoft   NaN  NaN   NaN
# 64                                                NaN   NaN  NaN   NaN
# 65                                                NaN   NaN  NaN   NaN
# 66                                                NaN   NaN  NaN   NaN
# 67                                                NaN   NaN  NaN   NaN
# 68                                                NaN   NaN  NaN   NaN
# 69                                                NaN   NaN  NaN   NaN
# 70                                                NaN   NaN  NaN   NaN
# 71             https://en.wikipedia.org/wiki/Alphabet   NaN  NaN   NaN
# 72        https://en.wikipedia.org/wiki/United_States   NaN  NaN   NaN
# 73           https://en.wikipedia.org/wiki/Google_Pay   NaN  NaN   NaN
# 74                                                NaN   NaN  NaN   NaN
# 75                                                NaN   NaN  NaN   NaN
# 76                                                NaN   NaN  NaN   NaN
# 77                                                NaN   NaN  NaN   NaN
# 78                                                NaN   NaN  NaN   NaN
# 79                                                NaN   NaN  NaN   NaN
# 80                                                NaN    12    4  2020
# 81                                                NaN   NaN  NaN  2020
# 82                                                NaN   NaN  NaN  2020
# 83                                                NaN   NaN  NaN   NaN
# 84                                                NaN   NaN  NaN   NaN
# 85                                                NaN   NaN  NaN   NaN
# 86                                                NaN   NaN  NaN   NaN
# 87                                                NaN   NaN  NaN   NaN
# 88                                                NaN   NaN  NaN   NaN
# 89                                                NaN   NaN  NaN   NaN
# 90                                                NaN   NaN  NaN   NaN
# 91                                                NaN   NaN  NaN   NaN
# 92                                                NaN   NaN  NaN   NaN
# 93                                                NaN   NaN  NaN   NaN
#
#    currency              value
# 0       NaN                NaN
# 1       NaN                NaN
# 2       NaN                NaN
# 3       NaN                NaN
# 4       NaN                NaN
# 5       NaN                NaN
# 6       NaN                NaN
# 7       NaN                NaN
# 8       NaN                NaN
# 9       NaN                NaN
# 10      NaN                NaN
# 11      NaN                NaN
# 12      NaN                NaN
# 13      NaN                NaN
# 14      NaN                NaN
# 15      NaN                NaN
# 16      NaN                NaN
# 17      NaN                NaN
# 18      NaN                NaN
# 19      NaN                NaN
# 20      NaN                NaN
# 21      NaN                NaN
# 22      NaN                NaN
# 23      NaN                NaN
# 24      NaN                NaN
# 25      NaN                NaN
# 26      NaN                NaN
# 27      NaN                NaN
# 28      NaN                NaN
# 29      NaN                NaN
# 30      NaN                NaN
# 31      NaN                NaN
# 32      NaN                NaN
# 33      NaN                NaN
# 34      NaN                NaN
# 35      NaN                NaN
# 36      NaN                NaN
# 37      NaN                NaN
# 38      NaN                NaN
# 39      NaN                NaN
# 40      NaN                NaN
# 41      NaN                NaN
# 42      NaN                NaN
# 43      NaN                NaN
# 44      NaN                NaN
# 45      NaN                NaN
# 46      NaN                NaN
# 47      NaN                NaN
# 48      NaN                NaN
# 49      NaN                NaN
# 50      NaN                NaN
# 51      NaN                NaN
# 52      NaN                NaN
# 53      NaN                NaN
# 54      NaN                NaN
# 55      NaN                NaN
# 56      NaN                NaN
# 57      NaN                NaN
# 58      NaN                NaN
# 59      NaN                NaN
# 60      NaN                NaN
# 61      NaN                NaN
# 62      NaN                NaN
# 63      NaN                NaN
# 64      NaN                NaN
# 65      NaN                NaN
# 66      NaN                NaN
# 67      NaN                NaN
# 68      NaN                NaN
# 69      NaN                NaN
# 70      NaN                NaN
# 71      NaN                NaN
# 72      NaN                NaN
# 73      NaN                NaN
# 74      NaN                NaN
# 75      NaN                NaN
# 76      NaN                NaN
# 77      NaN                NaN
# 78      NaN                NaN
# 79      NaN                NaN
# 80      NaN                NaN
# 81      NaN                NaN
# 82      NaN                NaN
# 83      EUR  1000000000.000000
# 84      USD  1200000000.000000
# 85      NaN               2020
# 86      NaN  1000000000.000000
# 87      NaN                  2
# 88      NaN               2020
# 89      NaN               2020
# 90      NaN  1200000000.000000
# 91      NaN                 10
# 92      NaN                  4
# 93      NaN                  2

# %% [markdown]
# #### Classify Documents
# Google Natual Language API classifies documents into these major categories: <br>
# Adult
#
# Arts & Entertainment
#
# Autos & Vehicles
#
# Beauty & Fitness
#
# Books & Literature
#
# Business & Industrial
#
# Computers & Electronics
#
# Finance
#
# Food & Drink
#
# Games
#
# Health
#
# Hobbies & Leisure
#
# Home & Garden
#
# Internet & Telecom
#
# Jobs & Education
#
# Law & Government
#
# News
#
# Online Communities
#
# People & Society
#
# Pets & Animals
#
# Real Estate
#
# Reference
#
# Science
#
# Sensitive Subjects
#
# Shopping
#
# Sports
#
# Travel
#
# A full list of categories and subcategories could be found here: https://cloud.google.com/natural-language/docs/categories

# %% [markdown]
# #### Analyze Sentiment
# Interpreting Google Sentiment Analysis Values:
#
# Sentiment Score - a number from -1.0 to 1.0 indicating how positive or negative the statement is.
#
# Sentiment Magnitude - a number ranging from 0 to infinity that represents the weight of sentiment expressed in the statement, regardless of being positive or negative. This value is often proportional to the length of the document.

# %%
# sentiment, magnitude, sentence_sentiment=gcp_analyze_sentiment(text) <- never declared
sentence_sentiment = analyze_text_sentiment(text)
# Out:
# text      : Deutsche Bank to Move ‘Heart’ of IT Systems Into Google’s Cloud
#  Steven Arons and Nico Grant
#  December 4, 2020
#  (Bloomberg) -- Deutsche Bank AG expects to ultimately replace large parts of its core banking system with alternatives powered by Alphabet Inc.’s Google, as the German lender embarks on its biggest effort yet to modernize computer systems that have hampered it for years.
#  The two companies on Friday finalized a cloud computing agreement under which the German lender plans to shift most of its data onto Google servers, technology head Bernd Leukert said in a phone interview. Both firms also agreed to jointly develop products including new lending offerings and retail apps.
#  The deal will include “applications at the heart of our IT,” Leukert said in an interview, adding that only Deutsche Bank will have the key to decrypt data it transfers to the cloud.
#  Cutting costs through automation and better technology are a centerpiece of the turnaround plan unveiled by Chief Executive Officer Christian Sewing last year. For Google, the deal is a step toward breaking into the growing cloud business with European banks. The business is currently dominated by Microsoft Corp. and Amazon.com Inc., a Bloomberg News analysis earlier this year showed.
#  Exactly how much of its systems Deutsche Bank will move into Google’s cloud will depend on “legal, regulatory and data privacy considerations,” Leukert said.
#  The two companies expect to sell some technology that they develop together to other financial services providers as white-label products and split the revenue, he said.
#  The contract is set to last at least 10 years and Deutsche Bank expects to make a cumulative return on investment of 1 billion euros ($1.2 billion) through the alliance, Bloomberg News previously reported.
#  Alphabet last month unveiled an expansion of Google Pay, partnering with banks and retailers in the U.S. to offer consumers new forms of bank accounts, cards and discounts. The upgraded payment system marks the tech giant’s deepest foray yet into the U.S. financial system.
#  For more articles like this, please visit us at bloomberg.com
#  ©2020 Bloomberg L.P.©2020 Bloomberg L.P.
# score     : 0.0%
# magnitude : 200.0%

# %%
df_sentiment = pd.DataFrame(sentence_sentiment)
df_sentiment
# Out:
#                                                  text  sentiment score  \
# 0   Deutsche Bank to Move ‘Heart’ of IT Systems In...             -0.1
# 1   The two companies on Friday finalized a cloud ...              0.0
# 2   Both firms also agreed to jointly develop prod...              0.3
# 3   The deal will include “applications at the hea...              0.0
# 4   Cutting costs through automation and better te...              0.3
# 5   For Google, the deal is a step toward breaking...             -0.1
# 6   The business is currently dominated by Microso...              0.0
# 7   Exactly how much of its systems Deutsche Bank ...             -0.1
# 8   The two companies expect to sell some technolo...              0.0
# 9   The contract is set to last at least 10 years ...             -0.1
# 10  Alphabet last month unveiled an expansion of G...              0.1
# 11  The upgraded payment system marks the tech gia...              0.3
# 12  For more articles like this, please visit us a...              0.0
#
#     sentiment magnitude
# 0                   0.1
# 1                   0.0
# 2                   0.3
# 3                   0.0
# 4                   0.3
# 5                   0.1
# 6                   0.0
# 7                   0.1
# 8                   0.0
# 9                   0.1
# 10                  0.1
# 11                  0.3
# 12                  0.0

# %% [markdown]
# ## Demo 2 - Process sample news articles from Refinitiv

# %%
from google.cloud import storage

#news_sample="github/gcp/FinancialServicesHeadline100.csv" 
news_sample="gs://ml-core-shared-standard-bucket/data/FinancialServicesHeadline100.csv"
df = pd.read_csv(news_sample)
print(df.shape)
df.head()
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# /opt/conda/lib/python3.7/site-packages/gcsfs/core.py in _get_object(self, path)
#     607         try:
# --> 608             res = await self._call("GET", "b/{}/o/{}", bucket, key, json_out=True)
#     609         except OSError as e:
#
# /opt/conda/lib/python3.7/site-packages/gcsfs/core.py in _call(self, method, path, json_out, info_out, *args, **kwargs)
#     530
# --> 531                 self.validate_response(status, contents, json, path, headers)
#     532                 break
#
# /opt/conda/lib/python3.7/site-packages/gcsfs/core.py in validate_response(self, status, content, json, path, headers)
#    1314             elif status == 403:
# -> 1315                 raise IOError("Forbidden: %s\n%s" % (path, msg))
#    1316             elif status == 502:
#
# OSError: Forbidden: https://www.googleapis.com/storage/v1/b/ml-core-shared-standard-bucket/o/data%2FFinancialServicesHeadline100.csv
# 231657102360-compute@developer.gserviceaccount.com does not have storage.objects.get access to the Google Cloud Storage object.
#
# During handling of the above exception, another exception occurred:
#
# OSError                                   Traceback (most recent call last)
# <ipython-input-30-c154c9246a9f> in <module>
#       3 #news_sample="github/gcp/FinancialServicesHeadline100.csv"
#       4 news_sample="gs://ml-core-shared-standard-bucket/data/FinancialServicesHeadline100.csv"
# ----> 5 df = pd.read_csv(news_sample)
#       6 print(df.shape)
#       7 df.head()
#
# /opt/conda/lib/python3.7/site-packages/pandas/io/parsers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options)
#     608     kwds.update(kwds_defaults)
#     609
# --> 610     return _read(filepath_or_buffer, kwds)
#     611
#     612
#
# /opt/conda/lib/python3.7/site-packages/pandas/io/parsers.py in _read(filepath_or_buffer, kwds)
#     460
#     461     # Create the parser.
# --> 462     parser = TextFileReader(filepath_or_buffer, **kwds)
#     463
#     464     if chunksize or iterator:
#
# /opt/conda/lib/python3.7/site-packages/pandas/io/parsers.py in __init__(self, f, engine, **kwds)
#     817             self.options["has_index_names"] = kwds["has_index_names"]
#     818
# --> 819         self._engine = self._make_engine(self.engine)
#     820
#     821     def close(self):
#
# /opt/conda/lib/python3.7/site-packages/pandas/io/parsers.py in _make_engine(self, engine)
#    1048             )
#    1049         # error: Too many arguments for "ParserBase"
# -> 1050         return mapping[engine](self.f, **self.options)  # type: ignore[call-arg]
#    1051
#    1052     def _failover_to_python(self):
#
# /opt/conda/lib/python3.7/site-packages/pandas/io/parsers.py in __init__(self, src, **kwds)
#    1865
#    1866         # open handles
# -> 1867         self._open_handles(src, kwds)
#    1868         assert self.handles is not None
#    1869         for key in ("storage_options", "encoding", "memory_map", "compression"):
#
# /opt/conda/lib/python3.7/site-packages/pandas/io/parsers.py in _open_handles(self, src, kwds)
#    1366             compression=kwds.get("compression", None),
#    1367             memory_map=kwds.get("memory_map", False),
# -> 1368             storage_options=kwds.get("storage_options", None),
#    1369         )
#    1370
#
# /opt/conda/lib/python3.7/site-packages/pandas/io/common.py in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     561         compression=compression,
#     562         mode=mode,
# --> 563         storage_options=storage_options,
#     564     )
#     565
#
# /opt/conda/lib/python3.7/site-packages/pandas/io/common.py in _get_filepath_or_buffer(filepath_or_buffer, encoding, compression, mode, storage_options)
#     332         try:
#     333             file_obj = fsspec.open(
# --> 334                 filepath_or_buffer, mode=fsspec_mode, **(storage_options or {})
#     335             ).open()
#     336         # GH 34626 Reads from Public Buckets without Credentials needs anon=True
#
# /opt/conda/lib/python3.7/site-packages/fsspec/core.py in open(self)
#     132         been deleted; but a with-context is better style.
#     133         """
# --> 134         out = self.__enter__()
#     135         closer = out.close
#     136         fobjects = self.fobjects.copy()[:-1]
#
# /opt/conda/lib/python3.7/site-packages/fsspec/core.py in __enter__(self)
#     100         mode = self.mode.replace("t", "").replace("b", "") + "b"
#     101
# --> 102         f = self.fs.open(self.path, mode=mode)
#     103
#     104         self.fobjects = [f]
#
# /opt/conda/lib/python3.7/site-packages/fsspec/spec.py in open(self, path, mode, block_size, cache_options, **kwargs)
#     934                 autocommit=ac,
#     935                 cache_options=cache_options,
# --> 936                 **kwargs
#     937             )
#     938             if not ac:
#
# /opt/conda/lib/python3.7/site-packages/gcsfs/core.py in _open(self, path, mode, block_size, cache_options, acl, consistency, metadata, autocommit, **kwargs)
#    1268             acl=acl,
#    1269             autocommit=autocommit,
# -> 1270             **kwargs,
#    1271         )
#    1272
#
# /opt/conda/lib/python3.7/site-packages/gcsfs/core.py in __init__(self, gcsfs, path, mode, block_size, autocommit, cache_type, cache_options, acl, consistency, metadata, content_type, callback_timeout, **kwargs)
#    1388             cache_type=cache_type,
#    1389             cache_options=cache_options,
# -> 1390             **kwargs,
#    1391         )
#    1392         bucket, key = self.fs.split_path(path)
#
# /opt/conda/lib/python3.7/site-packages/fsspec/spec.py in __init__(self, fs, path, mode, block_size, autocommit, cache_type, cache_options, **kwargs)
#    1255         if mode == "rb":
#    1256             if not hasattr(self, "details"):
# -> 1257                 self.details = fs.info(path)
#    1258             self.size = self.details["size"]
#    1259             self.cache = caches[cache_type](
#
# /opt/conda/lib/python3.7/site-packages/fsspec/asyn.py in wrapper(*args, **kwargs)
#     119     def wrapper(*args, **kwargs):
#     120         self = obj or args[0]
# --> 121         return maybe_sync(func, self, *args, **kwargs)
#     122
#     123     return wrapper
#
# /opt/conda/lib/python3.7/site-packages/fsspec/asyn.py in maybe_sync(func, self, *args, **kwargs)
#      98         if inspect.iscoroutinefunction(func):
#      99             # run the awaitable on the loop
# --> 100             return sync(loop, func, *args, **kwargs)
#     101         else:
#     102             # just call the blocking function
#
# /opt/conda/lib/python3.7/site-packages/fsspec/asyn.py in sync(loop, func, callback_timeout, *args, **kwargs)
#      69     if error[0]:
#      70         typ, exc, tb = error[0]
# ---> 71         raise exc.with_traceback(tb)
#      72     else:
#      73         return result[0]
#
# /opt/conda/lib/python3.7/site-packages/fsspec/asyn.py in f()
#      53             if callback_timeout is not None:
#      54                 future = asyncio.wait_for(future, callback_timeout)
# ---> 55             result[0] = await future
#      56         except Exception:
#      57             error[0] = sys.exc_info()
#
# /opt/conda/lib/python3.7/site-packages/gcsfs/core.py in _info(self, path, **kwargs)
#     824         # Check exact file path
#     825         try:
# --> 826             return await self._get_object(path)
#     827         except FileNotFoundError:
#     828             pass
#
# /opt/conda/lib/python3.7/site-packages/gcsfs/core.py in _get_object(self, path)
#     611                 raise
#     612             resp = await self._call(
# --> 613                 "GET", "b/{}/o/", bucket, json_out=True, prefix=key, maxResults=1
#     614             )
#     615             for item in resp.get("items", []):
#
# /opt/conda/lib/python3.7/site-packages/gcsfs/core.py in _call(self, method, path, json_out, info_out, *args, **kwargs)
#     529                         json = None
#     530
# --> 531                 self.validate_response(status, contents, json, path, headers)
#     532                 break
#     533             except (HttpError, RequestException, GoogleAuthError, ChecksumError) as e:
#
# /opt/conda/lib/python3.7/site-packages/gcsfs/core.py in validate_response(self, status, content, json, path, headers)
#    1313                 raise FileNotFoundError
#    1314             elif status == 403:
# -> 1315                 raise IOError("Forbidden: %s\n%s" % (path, msg))
#    1316             elif status == 502:
#    1317                 raise ProxyError()
#
# OSError: Forbidden: https://www.googleapis.com/storage/v1/b/ml-core-shared-standard-bucket/o/
# 231657102360-compute@developer.gserviceaccount.com does not have storage.objects.list access to the Google Cloud Storage bucket.

# %%
text=df["headline"]
print("size of document:", text.shape)
text.head()

# %%
# Combine all news into one document
text_all= df["headline"].to_string(index=False)
#print(text_all)

# %% [markdown]
# #### Analyze Syntax
# Syntactic Analysis breaks up the given text into a series of sentences and tokens and provides linguistic information about those tokens

# %%
# Process each news as a separate document

df_text_syntax=pd.DataFrame()
for text in df["headline"]:
    item=gcp_analyze_syntax(text)
    df_text_syntax=df_text_syntax.append(pd.DataFrame(item))

# %%
print("size of output:", df_text_syntax.shape)
df_text_syntax.head(50)

# %% [markdown]
# #### Analyze Entities
# Entity Analysis inspects the given text for known entities (proper nouns such as public figures, landmarks, etc.), and returns information about those entities.

# %%
# Process each article independently

df_entities=pd.DataFrame()
for text in df["headline"]:
    item=pd.DataFrame(gcp_analyze_entities(text))
    df_entities=df_entities.append(item, ignore_index=True)
# entities=gcp_analyze_entities(text_all)
# df_entities2 = pd.DataFrame(entities)

# %%
print("size of output:", df_entities.shape)
df_entities.head(50)

# %% [markdown]
# #### Classify Documents
# Google Natual Language API classifies documents into these major categories: <br>
# Adult
#
# Arts & Entertainment
#
# Autos & Vehicles
#
# Beauty & Fitness
#
# Books & Literature
#
# Business & Industrial
#
# Computers & Electronics
#
# Finance
#
# Food & Drink
#
# Games
#
# Health
#
# Hobbies & Leisure
#
# Home & Garden
#
# Internet & Telecom
#
# Jobs & Education
#
# Law & Government
#
# News
#
# Online Communities
#
# People & Society
#
# Pets & Animals
#
# Real Estate
#
# Reference
#
# Science
#
# Sensitive Subjects
#
# Shopping
#
# Sports
#
# Travel
#
# A full list of categories and subcategories could be found here:
# https://cloud.google.com/natural-language/docs/categories

# %%
## Overall document classification
gcp_classify_text(text_all)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-26-d296250c406d> in <module>
#       1 ## Overall document classification
# ----> 2 gcp_classify_text(text_all)
#
# NameError: name 'text_all' is not defined

# %%
# Process each article independently

df_sentiment=pd.DataFrame()
item_sentiment=pd.DataFrame(columns=["text", "sentiment score","sentiment magnitude"])
for text in df["headline"]:
    sentiment, magnitude, sentence_sentiment=gcp_analyze_sentiment(text)
    #item=pd.DataFrame(sentence_sentiment)
    #df_sentiment=df_sentiment.append(item, ignore_index=True)
    item_sentiment.loc[0, "text"]=text
    item_sentiment.loc[0, "sentiment score"]=sentiment
    item_sentiment.loc[0,"sentiment magnitude"]=magnitude
    df_sentiment=df_sentiment.append(item_sentiment, ignore_index=True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-27-8ea161386471> in <module>
#       3 df_sentiment=pd.DataFrame()
#       4 item_sentiment=pd.DataFrame(columns=["text", "sentiment score","sentiment magnitude"])
# ----> 5 for text in df["headline"]:
#       6     sentiment, magnitude, sentence_sentiment=gcp_analyze_sentiment(text)
#       7     #item=pd.DataFrame(sentence_sentiment)
#
# NameError: name 'df' is not defined

# %%
df_sentiment.head(100)

# %%
# Plot Sentiment Scores
import matplotlib.pyplot as plt
import seaborn as sns
from matplotlib import colors
from matplotlib.ticker import PercentFormatter
plt.rcParams.update({'figure.figsize':(16,8)})

x = df_sentiment["sentiment score"]
y =  df_sentiment["sentiment magnitude"]

sns.scatterplot(data= df_sentiment[["sentiment score", "sentiment magnitude"]])
                
n_bins=30

#plt.hist(x, bins=n_bins)
#plt.show()

fig, axs = plt.subplots(1, 2, sharey=True, tight_layout=True)
# We can set the number of bins with the `bins` kwarg
axs[0].set_xlabel("Sentiment Score")
axs[0].set_ylabel("percentage")
axs[0].set_title('Histogram of Sentiment Score')
axs[1].set_xlabel("Sentiment Magnitude")
axs[1].set_title('Histogram of Sentiment Magnitude')

axs[0].hist(x, bins=n_bins)
axs[1].hist(y, bins=n_bins)
plt.show()


fig, ax = plt.subplots(tight_layout=True)
hist = ax.hist2d(x, y, norm=colors.LogNorm())
plt.title("Sentiment Score and Magnitude 2-D Distribution")
ax.set_xlabel("Sentiment Score")
ax.set_ylabel("Sentiment Magnitude")

plt.show()

# %%
df_sentiment_all.head(10)
